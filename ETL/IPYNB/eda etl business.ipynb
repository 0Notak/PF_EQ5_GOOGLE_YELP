# %% [markdown]
# # Análisis Exploratorio de Datos ##

# %% [markdown]
# En el presente notebook se realizará un análisis exploratorio de los datos contenidos dentro del archivo **Bussines PKL**

# %%
import pandas as pd
import warnings
from locale import setlocale, LC_ALL
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
df_business= pd.read_pickle('business.pkl')
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# 2  32.223236 -110.880452   3.5           22  ...   NaN         NaN      NaN
# 3  39.955505  -75.155564   4.0           80  ...   NaN         NaN      NaN
# 4  40.338183  -75.471659   4.5           13  ...   NaN         NaN      NaN
#
#   longitude stars review_count is_open attributes categories hours
# 0       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 1       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 2       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 3       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 4       NaN   NaN          NaN     NaN        NaN        NaN   NaN
#
# [5 rows x 28 columns]

# %%
# Revisa las dimensiones del Dataframe
shape = df_business.shape
print(f"Número de registros: {shape[0]:,}")
print(f"Columnas: {shape[1]}")
# Out:
# Número de registros: 150,346
# Columnas: 28

# %% [markdown]
# Manejo de Columnas Duplicadas

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
#  17  city          5 non-null       object
#  18  state         5 non-null       object
#  19  postal_code   5 non-null       object
#  20  latitude      5 non-null       object
#  21  longitude     5 non-null       object
#  22  stars         5 non-null       object
#  23  review_count  5 non-null       object
#  24  is_open       5 non-null       object
#  25  attributes    5 non-null       object
#  26  categories    5 non-null       object
#  27  hours         5 non-null       object
# dtypes: object(28)
# memory usage: 33.3+ MB

# %%
df_business = df_business.loc[:, ~df_business.columns.duplicated()]
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: object(14)
# memory usage: 17.2+ MB

# %%
df_business.head(3)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
#
#     latitude   longitude stars review_count is_open  \
# 0  34.426679 -119.711197   5.0            7       0
# 1  38.551126  -90.335695   3.0           15       1
# 2  32.223236 -110.880452   3.5           22       0
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...

# %%
#Numero de negocios por categorias
df_business.categories.value_counts()
# Out:
# categories
# Beauty & Spas, Nail Salons                                                                                       1012
# Restaurants, Pizza                                                                                                935
# Nail Salons, Beauty & Spas                                                                                        934
# Pizza, Restaurants                                                                                                823
# Restaurants, Mexican                                                                                              728
#                                                                                                                  ...
# Dermatologists, Health & Medical, Cosmetic Surgeons, Doctors, Acne Treatment, Skin Care, Beauty & Spas              1
# Home Services, Home & Garden, Nurseries & Gardening, Hardware Stores, Shopping, Building Supplies, Appliances       1
# Food Trucks, Smokehouse, Restaurants, Food, Barbeque, Soul Food, Food Stands                                        1
# Assisted Living Facilities, Memory Care, Health & Medical, Hospice                                                  1
# Beauty & Spas, Permanent Makeup, Piercing, Tattoo                                                                   1
# Name: count, Length: 83160, dtype: int64

# %% [markdown]
# # Manejo de Duplicados -_- Se eliminan **102** *registros duplicados*  en las columna 'categories'

# %%
#Conteo de valores duplicados para las categorias

print("Los duplicados en 'categories' son:",df_business.categories.duplicated().sum())
# Out:
# Los duplicados en 'categories' son: 67185

# %%
# Se eliminan los valores duplicados en "categories":

df_business = df_business.dropna(subset=['categories'])
print("Los duplicados en 'categories' son:",df_business.categories.duplicated().sum())
# Out:
# Los duplicados en 'categories' son: 67083

# %%
# Identificamos el numero de negocios para cada estado en USA contenido en nuestro dataframe
df_business['state'].value_counts()
# Out:
# state
# PA     34013
# FL     26311
# TN     12045
# IN     11238
# MO     10909
# LA      9917
# AZ      9907
# NJ      8529
# NV      7712
# AB      5571
# CA      5201
# ID      4463
# DE      2261
# IL      2142
# TX         4
# CO         3
# WA         2
# HI         2
# MA         2
# NC         1
# UT         1
# MT         1
# MI         1
# SD         1
# XMS        1
# VI         1
# VT         1
# Name: count, dtype: int64

# %%
# Las coordenadas 32.321964, -110.928171, corresponden a la ciudad de Tucson, Arizona, en los Estados Unidos AZ
df_business[df_business.state == 'XMS']
# Out:
#                   business_id                      name  \
# 98688  X6y6DsgzGqb9v6Z53rvX9A  Bloom Salon & Beauty Bar
#
#                             address    city state postal_code   latitude  \
# 98688  6370 N Campbell Ave, Ste 140  Tucson   XMS       85718  32.321964
#
#         longitude stars review_count is_open  \
# 98688 -110.928171   4.5           29       1
#
#                                               attributes  \
# 98688  {'BusinessAcceptsCreditCards': 'True', 'HairSp...
#
#                                               categories  \
# 98688  Hair Stylists, Blow Dry/Out Services, Hair Sal...
#
#                                                    hours
# 98688  {'Monday': '0:0-0:0', 'Tuesday': '8:0-12:0', '...

# %%
# Las coordenadas 39.479779, -39.479779, corresponden a la ciudad de Reno, Nevada, en los Estados Unidos NV
df_business[df_business.state == 'SD']
# Out:
#                   business_id             name             address  city  \
# 88416  DWGAjqjxTeQ6_z5PhiNyWQ  Absolute Dental  5032 S Virginia St  Reno
#
#       state postal_code   latitude   longitude stars review_count is_open  \
# 88416    SD       89502  39.479779 -119.790018   2.5           39       1
#
#                                               attributes  \
# 88416  {'ByAppointmentOnly': 'False', 'AcceptsInsuran...
#
#                                               categories  \
# 88416  General Dentistry, Cosmetic Dentists, Health &...
#
#                                                    hours
# 88416  {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...

# %%
# Obtener el listado de codigos postales para USA
codigos_postales = df_business['postal_code'].unique()
ZIPCODEFULL = pd.DataFrame(codigos_postales, columns=['CODIG_POST-EU'])

# %%
 #  Instanciamos los codigos postales de CA para poder realizar un remplazo de los codigos que no estan correctos
import requests
ZipCode_CA = [] 

for codigo_postal in ZIPCODEFULL['CODIG_POST-EU']:
    url = f"http://api.zippopotam.us/us/{codigo_postal}"
    respuesta = requests.get(url)
    if respuesta.status_code == 200:
        datos = respuesta.json()
        if datos['places']:
            lugar = datos['places'][0]
            if lugar['state abbreviation'] == 'CA':
                ZipCode_CA.append(codigo_postal)
    else:
        pass

print(ZipCode_CA)   
num_elements = len(ZipCode_CA)
print("Codigos encontrados en Dataframe df_business: para CA", num_elements)
# Out:
# ['93101', '93103', '93105', '93109', '93117', '93013', '93108', '93110', '93118', '93111', '93190', '96161', '93106', '93001', '93140', '90261', '93102', '93067', '93160', '93041', '93121', '93130', '91307', '96143', '92260', '93120', '90041', '92805', '92324', '93031', '93014', '93030', '90703', '95050', '94960', '93199', '91355', '92026', '93107', '94804', '96150', '95661', '93150', '91390', '91306', '93642', '92626', '93907']
# Codigos encontrados en Dataframe df_business: para CA 48

# %%
df_business.loc[df_business['postal_code'].isin(ZipCode_CA), 'state'] = 'CA'
df_business['state'].value_counts()
# Out:
# state
# PA     32847
# FL     25413
# TN     11645
# IN     10844
# MO     10539
# CA     10223
# LA      9567
# AZ      9518
# NJ      8223
# NV      7439
# AB      5396
# ID      4308
# DE      2192
# IL      2066
# TX         4
# CO         3
# WA         2
# HI         2
# MA         2
# SD         1
# VI         1
# XMS        1
# UT         1
# MI         1
# MT         1
# NC         1
# VT         1
# Name: count, dtype: int64

# %%
# Identifico el número de los negocios para el estado de California
filtrado= df_business[df_business['state']=='CA']
filtrado['categories'].value_counts()
# Out:
# categories
# Restaurants, Mexican                                                                66
# Beauty & Spas, Nail Salons                                                          57
# Restaurants, Pizza                                                                  54
# Mexican, Restaurants                                                                39
# Pizza, Restaurants                                                                  37
#                                                                                     ..
# Event Photography, Event Planning & Services, Photographers, Session Photography     1
# Bakeries, Desserts, Food                                                             1
# Periodontists, Health & Medical, Cosmetic Dentists, General Dentistry, Dentists      1
# Restaurants, Asian Fusion, Thai, Taiwanese, Noodles                                  1
# Restaurants, Specialty Food, Food, Sandwiches, Italian                               1
# Name: count, Length: 7620, dtype: int64

# %%
#Filtro los negocios para la categoria que contenga la palabra restaurant en todo el dataset
df_restaurantes= df_business[df_business['categories'].str.lower().str.contains('restaurant')].reset_index(drop=True)
df_restaurantes.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
#De los 52286 registros observamos que Philadelphia no pertence a California 
# el codigo 19107 pertenece a  Pennsylvania
df_restaurantes
# Out:
#                   business_id                           name  \
# 0      MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1      CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2      k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3      bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 4      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                       ...                            ...
# 52281  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 52282  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 52283  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 52284  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 52285  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address             city state postal_code   latitude  \
# 0                935 Race St     Philadelphia    CA       19107  39.955505
# 1              615 S Main St     Ashland City    AZ       37015  36.269593
# 2          8025 Mackenzie Rd           Affton    TN       63123  38.565165
# 3        2312 Dickerson Pike        Nashville    MO       37207  36.208102
# 4                                   Tampa Bay    MO       33602  27.955269
# ...                      ...              ...   ...         ...        ...
# 52281        19 N Bishop Ave  Clifton Heights    TN       19018  39.925656
# 52282    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 52283          1108 S 9th St     Philadelphia    MO       19147  39.935982
# 52284        4405 Pennell Rd            Aston    PA       19014  39.856185
# 52285  2470 Guardian Road NW         Edmonton    NJ     T5T 1K8  53.509649
#
#         longitude stars review_count is_open  \
# 0      -75.155564   4.0           80       1
# 1      -87.058943   2.0            6       1
# 2      -90.321087   3.0           19       0
# 3       -86.76817   1.5           10       1
# 4       -82.45632   4.0           10       1
# ...           ...   ...          ...     ...
# 52281  -75.310344   3.0           11       1
# 52282 -116.284689   4.0           33       1
# 52283  -75.158665   4.5           35       1
# 52284  -75.427725   4.5           14       1
# 52285 -113.675999   4.5           18       0
#
#                                               attributes  \
# 0      {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 1      {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 2      {'Caters': 'True', 'Alcohol': 'u'full_bar'', '...
# 3      {'RestaurantsAttire': ''casual'', 'Restaurants...
# 4      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...
# ...                                                  ...
# 52281  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 52282  {'WiFi': ''free'', 'RestaurantsGoodForGroups':...
# 52283  {'WheelchairAccessible': 'False', 'Restaurants...
# 52284  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 52285  {'Ambience': '{'touristy': False, 'hipster': F...
#
#                                               categories  \
# 0      Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1      Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 2      Pubs, Restaurants, Italian, Bars, American (Tr...
# 3      Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 4             Vietnamese, Food, Restaurants, Food Trucks
# ...                                                  ...
# 52281  Restaurants, Sandwiches, Convenience Stores, C...
# 52282  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 52283                               Restaurants, Mexican
# 52284  Restaurants, Comfort Food, Food, Food Trucks, ...
# 52285                        Middle Eastern, Restaurants
#
#                                                    hours
# 0      {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 1      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 2                                                   None
# 3      {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 4      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# ...                                                  ...
# 52281  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 52282  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
# 52283  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 52284  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 52285  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
# [52286 rows x 14 columns]

# %%
# Filtramos solo los restaurantes de el Estado no 06 en USA  California 
df_restaurantes_CA = df_restaurantes[df_restaurantes['state'].eq('CA') & df_restaurantes['postal_code'].isin(ZipCode_CA)]
df_restaurantes_CA
# Out:
#                   business_id                             name  \
# 37     IDtLPgUrqorrpqSLdfMhZQ             Helena Avenue Bakery
# 55     SZU9c8V2GuREDN5KgyHFJw  Santa Barbara Shellfish Company
# 146    4xhGQGdGqU60BIznBjqnuA     California Tacos and Taproom
# 154    ifjluUv4VASwmFqEp8cWlQ                    Marty's Pizza
# 166    VeFfrEZ4iWaecrQg6Eq4cg                         Cal Taco
# ...                       ...                              ...
# 52222  izSgTrqebu8bN8ONOCs6cQ                       Oat Bakery
# 52241  2xxkaRy7rP5EUyjFt2J5kA                      Nikka Ramen
# 52253  TSwMwVq5GtQh5LW2t32uGA      Woody's Roundup Bar & Grill
# 52263  8BUr8GviR2o_b-brO21wwQ                Kyle's Isla Vista
# 52271  uriD7RFuHhLJeDdKaf0nFA                       Pizza Guru
#
#                                         address           city state  \
# 37                        131 Anacapa St, Ste C  Santa Barbara    CA
# 55                            230 Stearns Wharf  Santa Barbara    CA
# 146                   956 Embarcadero Del Norte     Isla Vista    CA
# 154                          2733 De La Vina St  Santa Barbara    CA
# 166                   7320 Hollister Ave, Ste 1         Goleta    CA
# ...                                         ...            ...   ...
# 52222                              5 W Haley St  Santa Barbara    CA
# 52241                           5701 Calle Real         Goleta    CA
# 52253  Earl Warren Showgrounds, 3400 Calle Real  Santa Barbara    CA
# 52263                   900 Embarcadero Del Mar     Isla Vista    CA
# 52271                             3534 State St  Santa Barbara    CA
#
#       postal_code   latitude   longitude stars review_count is_open  \
# 37          93101  34.414445 -119.690672   4.0          389       1
# 55          93101  34.408715 -119.685019   4.0         2404       1
# 146         93117  34.411555 -119.855077   4.0           49       0
# 154         93105  34.436236 -119.726147   4.0           64       1
# 166         93117  34.430542 -119.882367   4.0          189       1
# ...           ...        ...         ...   ...          ...     ...
# 52222       93101  34.416548 -119.695626   5.0          123       1
# 52241       93117  34.440885 -119.823523   4.5          562       1
# 52253       93105  34.430895 -119.735645   2.0            6       0
# 52263       93117  34.412966 -119.856886   2.5           12       1
# 52271       93105  34.440689 -119.739681   4.0          299       0
#
#                                               attributes  \
# 37     {'RestaurantsTakeOut': 'True', 'NoiseLevel': '...
# 55     {'OutdoorSeating': 'True', 'RestaurantsAttire'...
# 146    {'Music': '{'dj': False, 'background_music': F...
# 154    {'Alcohol': 'u'none'', 'BusinessAcceptsCreditC...
# 166    {'RestaurantsGoodForGroups': 'True', 'Business...
# ...                                                  ...
# 52222  {'Alcohol': 'u'none'', 'HasTV': 'False', 'Bike...
# 52241  {'ByAppointmentOnly': 'False', 'Alcohol': 'u'b...
# 52253  {'Caters': 'True', 'BusinessParking': '{'garag...
# 52263  {'OutdoorSeating': 'True', 'BusinessAcceptsBit...
# 52271  {'NoiseLevel': 'u'average'', 'RestaurantsGoodF...
#
#                                               categories  \
# 37     Food, Restaurants, Salad, Coffee & Tea, Breakf...
# 55     Live/Raw Food, Restaurants, Seafood, Beer Bar,...
# 146    Mexican, Beer Bar, Bars, Sports Bars, Nightlif...
# 154                                   Pizza, Restaurants
# 166    Burgers, Cafes, Restaurants, Mexican, American...
# ...                                                  ...
# 52222  Bakeries, Vegan, Specialty Food, Food Delivery...
# 52241                       Restaurants, Japanese, Ramen
# 52253             Barbeque, Bars, Restaurants, Nightlife
# 52263  Restaurants, Burgers, Food, Ice Cream & Frozen...
# 52271                           Restaurants, Pizza, Food
#
#                                                    hours
# 37     {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...
# 55     {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 146    {'Monday': '0:0-0:0', 'Tuesday': '10:0-22:0', ...
# 154    {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...
# 166    {'Monday': '0:0-0:0', 'Tuesday': '8:0-20:30', ...
# ...                                                  ...
# 52222  {'Monday': '0:0-0:0', 'Tuesday': '9:0-18:0', '...
# 52241  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-2...
# 52253                                               None
# 52263                                               None
# 52271  {'Monday': '15:0-21:0', 'Tuesday': '15:0-21:0'...
#
# [1164 rows x 14 columns]

# %%
df_restaurantes_CA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1164 entries, 37 to 52271
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   1164 non-null   object
#  1   name          1164 non-null   object
#  2   address       1164 non-null   object
#  3   city          1164 non-null   object
#  4   state         1164 non-null   object
#  5   postal_code   1164 non-null   object
#  6   latitude      1164 non-null   object
#  7   longitude     1164 non-null   object
#  8   stars         1164 non-null   object
#  9   review_count  1164 non-null   object
#  10  is_open       1164 non-null   object
#  11  attributes    1154 non-null   object
#  12  categories    1164 non-null   object
#  13  hours         992 non-null    object
# dtypes: object(14)
# memory usage: 136.4+ KB

# %%
# Selecionamos los restaurantes abiertos
df_restaurantes_CA= df_restaurantes_CA[df_restaurantes_CA['is_open']==1].reset_index(drop=True)

# %%
#eliminar columnas que no se van a utiliza
df_restaurantes_CA.drop(columns=['is_open','state'], inplace=True)
df_restaurantes_CA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   671 non-null    object
#  1   name          671 non-null    object
#  2   address       671 non-null    object
#  3   city          671 non-null    object
#  4   postal_code   671 non-null    object
#  5   latitude      671 non-null    object
#  6   longitude     671 non-null    object
#  7   stars         671 non-null    object
#  8   review_count  671 non-null    object
#  9   attributes    665 non-null    object
#  10  categories    671 non-null    object
#  11  hours         637 non-null    object
# dtypes: object(12)
# memory usage: 63.0+ KB

# %%
# Identificamos cuantos tipos de negocios existen ofreciendo servicios
df_restaurantes_CA.categories.value_counts()
# Out:
# categories
# Restaurants, Mexican                                                                                                                             21
# Mexican, Restaurants                                                                                                                             13
# Restaurants, Pizza                                                                                                                                8
# Thai, Restaurants                                                                                                                                 4
# Sushi Bars, Japanese, Restaurants                                                                                                                 3
#                                                                                                                                                  ..
# Restaurants, Food, Fast Food, Burgers, Coffee & Tea                                                                                               1
# Lounges, Art Galleries, American (New), Bars, Shopping, Nightlife, Restaurants, Music Venues, Gastropubs, Cocktail Bars, Arts & Entertainment     1
# Juice Bars & Smoothies, Food, Restaurants, Vegetarian                                                                                             1
# Cocktail Bars, Wine Bars, Nightlife, Bars, Beer Bar, Restaurants                                                                                  1
# Restaurants, Burgers, Food, Ice Cream & Frozen Yogurt, American (Traditional), Salad                                                              1
# Name: count, Length: 595, dtype: int64

# %%
#Filtro los servicios solo para California
categorias_unicas = df_restaurantes_CA['categories'].unique()
for categoria in categorias_unicas:
    print(categoria)
# Out:
# Food, Restaurants, Salad, Coffee & Tea, Breakfast & Brunch, Sandwiches, Bakeries
# Live/Raw Food, Restaurants, Seafood, Beer Bar, Beer, Wine & Spirits, Bars, Food, Nightlife
# Pizza, Restaurants
# Burgers, Cafes, Restaurants, Mexican, American (Traditional)
# Food, Restaurants, Chinese, Bubble Tea, Vietnamese
# Chicken Wings, Salad, Restaurants, Pizza, Italian, Sandwiches
# Restaurants, Thai
# Themed Cafes, Cafes, Pets, Arts & Entertainment, Women's Clothing, Coffee & Tea, Shopping, Pet Adoption, Fashion, Pet Sitting, Accessories, Pet Stores, Pet Services, Food, Restaurants
# Food, Food Delivery Services, Burgers, Pizza, Caterers, Event Planning & Services, Restaurants
# Wineries, Food, Restaurants, Arts & Entertainment, Festivals, Food Stands
# Breweries, Shopping, Food Court, Food, Venues & Event Spaces, Restaurants, Event Planning & Services, Wineries, Wine Tasting Room, Arts & Entertainment, Shopping Centers
# Chinese, Restaurants, Asian Fusion, Szechuan
# Food, Vietnamese, Restaurants, Bubble Tea
# Sandwiches, Restaurants, Salad, Hot Dogs, Delis
# Sandwiches, Specialty Food, Food, Health Markets, Juice Bars & Smoothies, Restaurants
# Restaurants, Fast Food, Chinese
# American (Traditional), Vegetarian, Restaurants
# Thai, Restaurants
# Restaurants, Soup, Salad, Thai
# Fast Food, Burgers, Restaurants
# American (Traditional), Restaurants, Seafood, Burgers, Tacos, Sandwiches, Mexican, Bars, Food, Beer Bar, Juice Bars & Smoothies, Nightlife
# Bars, Burgers, Restaurants, Nightlife, Sports Bars, American (New)
# Mexican, Restaurants, Food Trucks, Food
# Mexican, Arts & Entertainment, Festivals, Restaurants, Religious Organizations, Churches
# Restaurants, Fast Food, Mexican, Tacos, Burgers, Breakfast & Brunch
# Restaurants, Sushi Bars
# Restaurants, American (Traditional), Food Delivery Services, Caterers, Venues & Event Spaces, Cocktail Bars, Bars, Wedding Planning, Nightlife, Food, Event Planning & Services
# Sushi Bars, Caterers, Food, Fast Food, Event Planning & Services, Japanese, Food Delivery Services, Korean, Restaurants, Specialty Food, Asian Fusion
# Mexican, Restaurants, Breakfast & Brunch
# American (Traditional), Vegan, Restaurants
# Tapas Bars, Nightlife, Salad, Restaurants, Cocktail Bars, Bars, Wine Bars, Cafes, Pizza, American (New)
# Seafood, Venues & Event Spaces, Cocktail Bars, Restaurants, Nightlife, Breakfast & Brunch, American (Traditional), Event Planning & Services, Bars, American (New)
# Breweries, Nightlife, Food, Cocktail Bars, Bars, Restaurants, Brewpubs, Gastropubs
# Food, Vegetarian, Salad, Restaurants, Cafes, American (Traditional), Burgers, Juice Bars & Smoothies
# Restaurants, Fast Food, Burgers
# Restaurants, Asian Fusion, Seafood, Sushi Bars, Japanese
# American (Traditional), Restaurants, Bars, Nightlife
# Mexican, Tacos, Restaurants
# Restaurants, American (Traditional), Nightlife, Bars, Cocktail Bars
# Mexican, Restaurants, Bakeries, Food, Sandwiches, Coffee & Tea
# Japanese, Restaurants, Asian Fusion, Fast Food
# Sushi Bars, Japanese, Restaurants
# Coffee & Tea, Breakfast & Brunch, Restaurants, American (New), Food
# Chicken Wings, Restaurants, Beer, Wine & Spirits, Sandwiches, Food, Pizza, Italian
# Mexican, Restaurants
# Health Markets, Coffee & Tea, Ice Cream & Frozen Yogurt, Restaurants, Juice Bars & Smoothies, Breakfast & Brunch, Food, American (New), Specialty Food
# Restaurants, Japanese, Sushi Bars
# Restaurants, Mexican
# Cooking Schools, Shopping, Cooking Classes, Restaurants, Caterers, Education, Cafes, Event Planning & Services, Specialty Schools, Arts & Crafts
# Event Planning & Services, Restaurants, Nightlife, Caterers, Italian, Bars
# American (Traditional), Breakfast & Brunch, Restaurants, American (New), Burgers
# Coffee & Tea, Noodles, Restaurants, Seafood, Japanese, Ramen, Food, Asian Fusion, Poke
# Restaurants, Food, American (New), Beer, Wine & Spirits
# Restaurants, Chinese, Fast Food
# Restaurants, Event Planning & Services, Party & Event Planning, Food, Venues & Event Spaces, Arts & Entertainment, Social Clubs, Specialty Food
# Hotels & Travel, Event Planning & Services, Cafes, Restaurants, Hotels
# Breakfast & Brunch, Burgers, American (Traditional), American (New), Restaurants
# Restaurants, Nightlife, Japanese, Bars
# Food, Italian, Restaurants
# Cosmetic Surgeons, Pizza, Doctors, Beauty & Spas, Nail Salons, Cosmetics & Beauty Supply, Chiropractors, Shopping, Restaurants, Health & Medical
# Restaurants, Chicken Wings, Chicken Shop, Fast Food
# Thai, Restaurants, American (New), Pop-Up Restaurants, Asian Fusion
# Japanese, Restaurants, Steakhouses, Asian Fusion
# Wedding Planning, Barbeque, Event Planning & Services, Restaurants, Caterers, Personal Chefs
# Restaurants, Delis, Food, Grocery
# Steakhouses, Sushi Bars, Restaurants, Japanese
# Restaurants, Breakfast & Brunch
# American (Traditional), Restaurants, Shopping Centers, Shopping, Local Flavor
# Restaurants, Barbeque, Mexican
# Restaurants, Cafes, Bagels, Food
# Bars, Restaurants, Nightlife, Sandwiches, American (New), Tapas Bars, Wine Bars
# Restaurants, American (Traditional), Lounges, Nightlife, Bars, Burgers, American (New)
# Salad, Sandwiches, Restaurants, Pizza
# Restaurants, Chinese
# Restaurants, American (Traditional), American (New), Salad, Pizza, Gluten-Free
# Sandwiches, Restaurants, American (New)
# Restaurants, Breakfast & Brunch, Cafes, Cajun/Creole
# Bubble Tea, Restaurants, Food, Asian Fusion, Vegan, Acai Bowls
# Coffee & Tea, Fast Food, Food, Restaurants, Burgers
# American (Traditional), Restaurants, Wine Bars, Pizza, Cocktail Bars, Bars, Vegan, Nightlife
# Food, Bubble Tea, Chinese, Restaurants, Asian Fusion, Hot Pot
# Restaurants, Mexican, Fast Food
# Restaurants, Event Planning & Services, Hotels, Hotels & Travel
# Food Trucks, Food, Restaurants, Mexican
# Mexican, American (Traditional), Burgers, Restaurants
# Pizza, Restaurants, Sandwiches, Salad
# Coffee Roasteries, Acai Bowls, Food, Coffee & Tea, Sandwiches, Bagels, Restaurants, Cafes
# Farmers Market, American (Traditional), American (New), Food, Restaurants
# Restaurants, Salad, Pizza, Chicken Wings
# Bakeries, Restaurants, Delis, Grocery, Specialty Food, Health Markets, Beer, Wine & Spirits, Food, American (New)
# Food, Juice Bars & Smoothies, Restaurants
# Bars, Mexican, Nightlife, Restaurants
# Nightlife, Arts & Entertainment, Restaurants, Dance Clubs, Bars, Music Venues, Mexican, Sports Bars
# Restaurants, Asian Fusion, Food, Poke, Hawaiian, Seafood
# American (Traditional), Restaurants, Bars, Cocktail Bars, Nightlife, American (New), Sandwiches
# Breakfast & Brunch, Restaurants, Bakeries, Food, Australian
# Restaurants, Seafood, American (New), Steakhouses
# Comfort Food, Bubble Tea, Restaurants, Tea Rooms, Asian Fusion, Coffee & Tea, Food
# Food, Burgers, Restaurants, Fast Food, Coffee & Tea
# Restaurants, Food, Desserts
# Coffee & Tea, Restaurants, Specialty Food, Beer, Wine & Spirits, Food, Health Markets, Grocery, Fruits & Veggies
# Restaurants, American (New), Barbeque, Food, Sandwiches, Wine Bars, Diners, Bars, Specialty Food, American (Traditional), Nightlife
# Tapas/Small Plates, Restaurants, Breakfast & Brunch, Seafood, American (New)
# Cajun/Creole, Restaurants, Breakfast & Brunch
# Mexican, Tacos, Restaurants, Barbeque, Food Delivery Services, Food Trucks, Food, Event Planning & Services, Caterers
# Salad, Sandwiches, Restaurants
# Restaurants, Vegetarian, Salad, Coffee & Tea, Tex-Mex, American (Traditional), Burgers, Food, Sandwiches, Mexican, Juice Bars & Smoothies
# Pizza, Nightlife, Italian, Bars, Restaurants, Wine Bars
# Restaurants, Coffee & Tea, Breakfast & Brunch, Food, Cafes
# Pop-Up Restaurants, Restaurants, Food, Donuts
# Lounges, American (New), Burgers, Cocktail Bars, Bars, Sports Bars, Nightlife, Restaurants
# Pizza, Gluten-Free, Restaurants, Event Planning & Services, Caterers
# Comfort Food, Bakeries, Food, Desserts, Restaurants, Empanadas, Argentine
# Latin American, Restaurants, Argentine, Empanadas, Food
# Japanese, Restaurants, Beer, Wine & Spirits, Food, Sushi Bars
# Coffee & Tea, Restaurants, Food
# Noodles, Restaurants, Gluten-Free, Creperies, Chinese, Asian Fusion
# Food, Asian Fusion, Bubble Tea, Restaurants, Japanese
# Ice Cream & Frozen Yogurt, Juice Bars & Smoothies, Restaurants, Specialty Food, Food
# Restaurants, Party & Event Planning, Specialty Food, Delis, Food, Meat Shops, Event Planning & Services, Caterers
# Juice Bars & Smoothies, Restaurants, Food
# Restaurants, Pizza, Chicken Wings, Sandwiches
# Food, Restaurants, Middle Eastern, Cafes, Bakeries
# American (New), Food, Specialty Food, Restaurants
# Food, Restaurants, Bakeries, Mexican, Breakfast & Brunch
# Food, Coffee & Tea, Restaurants
# Delis, Restaurants, Grocery, American (New), Cafes, Coffee & Tea, Beer, Wine & Spirits, Food
# Cafes, Burgers, Sandwiches, Restaurants
# Wine Tasting Room, Tasting Classes, Bars, Wineries, Wine Bars, Tours, Food, Education, Wine Tasting Classes, Restaurants, Hotels & Travel, Nightlife, Barbeque, Wine Tours, Arts & Entertainment
# Restaurants, American (New), Seafood, Italian, Pizza
# Pizza, Restaurants, Chicken Wings, Salad, Sandwiches
# Food, Cafes, Bakeries, Restaurants
# Juice Bars & Smoothies, Breakfast & Brunch, Brazilian, Restaurants, Food, Salad, Acai Bowls
# Active Life, Restaurants, Boating
# Sushi Bars, Restaurants, Japanese
# Breakfast & Brunch, Diners, Nightlife, Restaurants, Comfort Food, American (New), Burgers, Salad
# Food, Mexican, Restaurants, Seafood, Desserts
# Restaurants, Fish & Chips, Food, Seafood, American (Traditional), Fast Food, Coffee & Tea, Breakfast & Brunch
# Restaurants, Italian
# Coffee & Tea, Food, Ice Cream & Frozen Yogurt, Restaurants, Cafes
# Restaurants, Pizza, Salad, Chicken Wings
# Restaurants, American (New), Italian, Breakfast & Brunch, Seafood
# Coffee & Tea, Breakfast & Brunch, Restaurants, French, Salad, Sandwiches, Desserts, Bakeries, Food
# Bakeries, Food, Breakfast & Brunch, Cafes, Restaurants
# Chinese, Restaurants
# Burgers, Restaurants, Fast Food
# Restaurants, Sandwiches, American (New)
# Sandwiches, Delis, Restaurants, Soup, Salad, Food
# Tacos, Restaurants, Mexican
# Delis, Food, Restaurants, Grocery
# Fish & Chips, Seafood, Restaurants
# Wine Tasting Room, Jazz & Blues, Tapas Bars, Wineries, Food, Wine Bars, Champagne Bars, Music Venues, Arts & Entertainment, Restaurants, Bakeries, Bars, Nightlife
# Food Trucks, Tacos, Mexican, Salad, Food, Restaurants
# Restaurants, Bakeries, Breakfast & Brunch, Food, Coffee Roasteries, Coffee & Tea
# Restaurants, Salad, Sandwiches, Italian, Pizza
# Food, Mexican, Restaurants, Bakeries
# Delis, Restaurants, Fast Food, Sandwiches
# Gluten-Free, American (New), Restaurants, Sandwiches, Salad, Steakhouses, Delis, American (Traditional)
# Fast Food, Restaurants, Sandwiches, Delis
# Seafood, American (New), Salad, Restaurants, Sandwiches
# Seafood, Breakfast & Brunch, American (Traditional), Restaurants, Burgers
# Mediterranean, Restaurants, Salad, Greek
# Delis, Salad, Restaurants, Sandwiches, Burgers, American (Traditional)
# Ramen, Vegetarian, Sushi Bars, Japanese, Restaurants
# Bars, Tapas Bars, Cocktail Bars, Restaurants, Nightlife, Speakeasies
# Burgers, Restaurants
# Cafes, Burgers, American (Traditional), Tacos, Seafood, Restaurants, Mexican
# Delis, Restaurants
# Restaurants, Food, Breweries, American (Traditional), Brewpubs
# Fast Food, Food, Acai Bowls, Juice Bars & Smoothies, Restaurants
# Restaurants, Chicken Wings, Sandwiches, Breakfast & Brunch, Pizza, Burgers
# Ethnic Food, Restaurants, Mexican, Specialty Food, Imported Food, Food
# Asian Fusion, Poke, Seafood, Food, Restaurants
# Restaurants, American (Traditional)
# Public Services & Government, Landmarks & Historical Buildings, Local Flavor, Restaurants, Tours, Shopping, Shopping Centers, Seafood, Hotels & Travel, Boat Tours
# Restaurants, Pizza
# Restaurants, Mexican, Food, Beer, Wine & Spirits
# Salad, Steakhouses, Restaurants, Nightlife, Seafood
# Restaurants, Vegan, Tapas/Small Plates, Vegetarian, Bars, Farmers Market, Beer, Wine & Spirits, Beer Bar, Food, Cafes, Nightlife, Wine Bars
# Vegetarian, Gluten-Free, Pizza, Caterers, Restaurants, Event Planning & Services
# Cocktail Bars, Fish & Chips, Nightlife, Seafood, Restaurants, Bars
# Delis, Food, Beer, Wine & Spirits, Convenience Stores, Grocery, Restaurants
# Restaurants, American (Traditional), Active Life, Golf
# Pop-Up Restaurants, Korean, Restaurants, Asian Fusion
# Breakfast & Brunch, Diners, Restaurants, American (Traditional)
# Latin American, Restaurants, Mexican, New Mexican Cuisine
# Restaurants, Breakfast & Brunch, American (Traditional)
# Steakhouses, Burgers, Bars, Seafood, Cocktail Bars, Restaurants, Nightlife
# Sandwiches, Pizza, Restaurants, Italian
# Pizza, Sandwiches, Chicken Wings, Restaurants
# Restaurants, American (Traditional), Breakfast & Brunch
# Italian, Restaurants
# Pop-Up Restaurants, Coffee & Tea, Food, Restaurants
# Food, Live/Raw Food, Restaurants, Ice Cream & Frozen Yogurt, Asian Fusion, Poke, Seafood, Food Delivery Services
# Food, Donuts, Restaurants, Sandwiches, Coffee & Tea
# Salad, Sandwiches, Restaurants, Delis
# Restaurants, Food, Coffee & Tea
# Food, Breakfast & Brunch, Grocery, Sandwiches, Beer, Wine & Spirits, Meat Shops, Delis, Specialty Food, Restaurants, Health Markets
# Restaurants, Salad, Sandwiches, Chicken Wings, Pizza
# Seafood, Specialty Food, Seafood Markets, Farmers Market, Restaurants, Food
# Restaurants, Sushi Bars, Japanese, Asian Fusion
# Restaurants, Pizza, Italian
# Sushi Bars, Restaurants
# Diners, Restaurants
# Restaurants, Bagels, Coffee & Tea, Food, Bubble Tea, Donuts
# Cocktail Bars, Wine Bars, Nightlife, Bars, Beer Bar, Restaurants
# Juice Bars & Smoothies, Food, Restaurants, Vegetarian
# Lounges, Art Galleries, American (New), Bars, Shopping, Nightlife, Restaurants, Music Venues, Gastropubs, Cocktail Bars, Arts & Entertainment
# Restaurants, Food, Fast Food, Burgers, Coffee & Tea
# Seafood, Restaurants, American (Traditional)
# Cafes, Restaurants, Cafeteria
# Restaurants, Bars, Breakfast & Brunch, American (Traditional), Nightlife
# Food, Restaurants, Mediterranean, Farmers Market, Specialty Food, Organic Stores, Street Vendors
# Restaurants, Sandwiches, Salad, Fast Food
# Fast Food, Chinese, Restaurants
# Active Life, Bowling, Restaurants, Bars, Nightlife, Party & Event Planning, Arcades, Event Planning & Services, Arts & Entertainment
# Farmers Market, Food, Fast Food, American (New), Bars, Wine Bars, Breakfast & Brunch, Cafes, Restaurants, Nightlife
# Fast Food, Restaurants, Coffee & Tea, Food, Burgers
# Ramen, Japanese, Restaurants
# Cheese Shops, Food, Arts & Crafts, Home Decor, Vegan, Honey, Restaurants, Souvenir Shops, Specialty Food, Wildlife Control, Home & Garden, Shopping, Local Services, Pest Control
# Restaurants, Food Delivery Services, Nightlife, Cocktail Bars, Food, Tapas Bars, Bars
# Wine Bars, Restaurants, Indian, Australian, Bars, American (New), Nightlife
# Restaurants, American (New)
# American (New), Food, Restaurants, American (Traditional)
# Gluten-Free, Gastropubs, Vegan, Restaurants, Indian
# Event Planning & Services, Food, Food Trucks, Restaurants, Pizza, Caterers, Barbeque
# Tuscan, Seafood, Wine Bars, Restaurants, Bars, Nightlife, Italian
# Steakhouses, American (Traditional), Desserts, Food, Restaurants
# Tex-Mex, Restaurants, Bars, American (Traditional), Nightlife
# French, American (New), Restaurants, Italian
# Restaurants, American (New), Mexican
# Restaurants, Breakfast & Brunch, American (Traditional), Burgers
# Beer Bar, Sports Bars, Pubs, Bars, Restaurants, Cocktail Bars, Gastropubs, Nightlife, Tapas Bars
# Restaurants, Tapas/Small Plates, Bars, Cocktail Bars, American (New), Italian, Vegetarian, Nightlife
# Burgers, Restaurants, Food
# Breakfast & Brunch, Restaurants, Mexican, American (Traditional)
# Sandwiches, Restaurants, American (Traditional), Beer, Wine & Spirits, Chicken Shop, Food, American (New), Burgers
# Desserts, Food, Bars, Wine Bars, Coffee & Tea, Nightlife, Tapas/Small Plates, Restaurants
# Restaurants, Fast Food, Tacos, Breakfast & Brunch, Burgers, Mexican
# Tex-Mex, Tacos, Restaurants, Fast Food, Breakfast & Brunch, Mexican
# Art Galleries, Wine Bars, Shopping, Nightlife, Restaurants, Wineries, Bars, Food, Arts & Entertainment
# American (New), Wraps, Chinese, Sushi Bars, Barbeque, Dim Sum, Asian Fusion, Ramen, Restaurants, Noodles, Soup, Japanese, Hot Pot
# Salad, Sandwiches, Vegetarian, Restaurants, Chicken Wings
# Hotels & Travel, Hotels, Event Planning & Services, Restaurants, Piano Bars, Nightlife
# Mexican, Restaurants, Breakfast & Brunch, Seafood
# Food, Food Delivery Services, Restaurants, Mexican
# Donuts, Restaurants, Bakeries, Food, Sandwiches
# American (Traditional), American (New), Breakfast & Brunch, Restaurants, Seafood, Vegetarian, Nightlife, Event Planning & Services, Bars, Venues & Event Spaces
# Cafes, Restaurants, Sandwiches, Chicken Shop, Salad, American (New), Burgers, Breakfast & Brunch
# Restaurants, Mexican, Salad
# Seafood, American (New), Sandwiches, Steakhouses, Restaurants, Bars, Nightlife
# Coffee & Tea, Food, Restaurants, Breakfast & Brunch, Bakeries, Sandwiches, Tabletop Games, Shopping
# Mexican, Bars, Tex-Mex, Nightlife, Dance Clubs, Sports Bars, Restaurants
# Wineries, Food, Breweries, Nightlife, Bars, Arts & Entertainment, Champagne Bars, Pubs, American (New), Brewpubs, Restaurants
# Restaurants, Donuts, Food, Coffee & Tea
# Health & Medical, Restaurants, Mexican, Cannabis Clinics, Barbeque
# Cajun/Creole, Breakfast & Brunch, Caterers, Restaurants, Event Planning & Services, Burgers
# Italian, Salad, Pizza, Restaurants, Sandwiches
# Restaurants, Burgers, Sandwiches, Pizza, American (Traditional), Breakfast & Brunch
# Restaurants, Food, Hot Dogs, Shaved Ice, Desserts
# Chicken Shop, Korean, Chicken Wings, Fast Food, American (New), Soul Food, Restaurants
# Restaurants, American (New), Breakfast & Brunch, Diners
# Restaurants, Nightlife, Mexican, Bars, Cocktail Bars
# Breweries, American (New), Arts & Entertainment, Music Venues, Restaurants, Brewpubs, Food, Nightlife
# Seafood, Nightlife, Hotels, Event Planning & Services, American (New), Bars, Diners, Restaurants, Hotels & Travel, Breakfast & Brunch
# Breakfast & Brunch, Juice Bars & Smoothies, Acai Bowls, Restaurants, Food
# Restaurants, Fish & Chips, Food, Specialty Food, Seafood Markets, American (Traditional), Seafood
# Pizza, Italian, Restaurants
# Food, Restaurants, Cafes, Coffee Roasteries, Coffee & Tea
# Chicken Wings, Restaurants, Pizza, Sandwiches
# Food, Breakfast & Brunch, Bakeries, Restaurants, Coffee & Tea
# Bars, Mediterranean, Burgers, Restaurants, Gastropubs, Nightlife, Whiskey Bars, Cocktail Bars
# Restaurants, Tex-Mex, Fast Food, Mexican, Tacos
# Health Markets, Food, Juice Bars & Smoothies, Specialty Food, Grocery, Restaurants, Delis, Meat Shops
# Restaurants, American (New), Bars, Nightlife, Seafood, Breakfast & Brunch, American (Traditional), Desserts, Food
# Salad, American (New), Restaurants, Tacos, Mexican
# Korean, Barbeque, Restaurants
# Mexican, Gluten-Free, Latin American, Restaurants, Salvadoran, Caterers, Event Planning & Services
# Cafes, Restaurants, Breakfast & Brunch
# Restaurants, Food, American (New), Wine Bars, Nightlife, Venues & Event Spaces, Bars, Event Planning & Services
# Sandwiches, Breakfast & Brunch, Restaurants, American (Traditional)
# Bakeries, Restaurants, Food, American (Traditional), Breakfast & Brunch, Coffee & Tea
# Food, Vietnamese, Restaurants, Noodles
# Restaurants, Beauty & Spas, American (New), Event Planning & Services, Hotels, Massage, Resorts, Day Spas, Hotels & Travel, Venues & Event Spaces
# Food, Bakeries, Restaurants, Patisserie/Cake Shop, Cafes, Coffee & Tea
# Vietnamese, Pizza, Breakfast & Brunch, Restaurants, Gluten-Free
# Pizza, Restaurants, Italian, Vegan, Gluten-Free, Sandwiches
# Restaurants, Bars, Caterers, Mexican, Salad, Event Planning & Services, Desserts, Food, Nightlife
# Italian, Restaurants, American (New), Mediterranean
# American (New), Tapas/Small Plates, Event Planning & Services, Venues & Event Spaces, Restaurants, Burgers
# Food, Fast Food, Restaurants, Burgers, American (Traditional), Coffee & Tea
# Cocktail Bars, Bars, Restaurants, Breakfast & Brunch, Nightlife, Seafood, Cuban
# Pizza, Restaurants, Chicken Wings, Sandwiches
# Restaurants, Barbeque, Food, Caterers, Event Planning & Services
# American (Traditional), Event Planning & Services, Caterers, Restaurants, American (New), Cafes, Sandwiches, Breakfast & Brunch
# Tapas/Small Plates, Desserts, Restaurants, Breakfast & Brunch, Food, Seafood
# Cafes, Restaurants, Bakeries, Coffee & Tea, Juice Bars & Smoothies, Food
# Delis, Sandwiches, Food, International Grocery, Restaurants, Ethnic Food, Grocery, Specialty Food
# Organic Stores, Breakfast & Brunch, Live/Raw Food, Juice Bars & Smoothies, Food, Restaurants
# Restaurants, Fast Food, Mexican, Burgers, Tacos, Breakfast & Brunch
# Szechuan, Chinese, Nightlife, Karaoke, Asian Fusion, Restaurants
# Restaurants, Event Planning & Services, American (Traditional), Venues & Event Spaces
# Delis, Sandwiches, American (New), Restaurants
# American (Traditional), Restaurants, Cafes, Coffee & Tea, Food
# Restaurants, Breakfast & Brunch, Latin American, Mexican, Seafood
# Chicken Wings, Restaurants
# Restaurants, Delis, Food, Specialty Food, Grocery, Sandwiches
# Sandwiches, Restaurants, Fast Food, Breakfast & Brunch
# Sandwiches, Breakfast & Brunch, Restaurants, Fast Food
# Burgers, American (New), Diners, Breakfast & Brunch, Fish & Chips, Restaurants
# Bakeries, Mexican, Restaurants, Food
# Ice Cream & Frozen Yogurt, Juice Bars & Smoothies, Convenience Stores, Vegan, Food, Health Markets, Specialty Food, Restaurants
# Restaurants, Breakfast & Brunch, American (New), American (Traditional), Burgers
# Wine Tours, Food Tours, Tours, Restaurants, Food, Arts & Entertainment, Hotels & Travel, Walking Tours
# Mediterranean, Bars, Restaurants, Nightlife
# Restaurants, Nightlife, Mexican, Bars, Breakfast & Brunch
# Music Venues, Bars, Nightlife, Arts & Entertainment, Restaurants, American (Traditional)
# Food, Juice Bars & Smoothies, Restaurants, Coffee & Tea, Breakfast & Brunch, Sandwiches
# Delis, Food, Restaurants, Bakeries
# Food, Restaurants, Delis, Event Planning & Services, Caterers, Sandwiches
# Restaurants, Sandwiches, Fast Food
# Korean, Restaurants, American (New), Mexican, Tacos, Nightlife, Fast Food, Bars
# Food, Italian, Pizza, Fast Food, Gelato, Chicken Wings, Sandwiches, Salad, Restaurants
# Restaurants, Salad, Soup, Sandwiches, Breakfast & Brunch
# Restaurants, Vegan, Gluten-Free, Falafel, Mediterranean, Salad, Sandwiches
# Restaurants, American (Traditional), Barbeque, Steakhouses, Sandwiches
# Lounges, Karaoke, American (New), Mexican, Sports Bars, Tacos, Restaurants, Pizza, Bars, Nightlife, Food, Beer, Wine & Spirits
# Bars, Tacos, Mexican, Food, Beer, Wine & Spirits, Beer Bar, Nightlife, Restaurants
# Desserts, Restaurants, Food, Breakfast & Brunch, Delis, Food Trucks
# Mexican, Restaurants, Desserts, Food
# Diners, Salad, American (Traditional), Breakfast & Brunch, Restaurants
# Caterers, Italian, Food Delivery Services, American (New), Event Planning & Services, Restaurants, Food
# Restaurants, Desserts, Sandwiches, Food, Italian
# Food, Coffee Roasteries, Restaurants, Coffee & Tea, Salad, Sandwiches
# Delis, Restaurants, Coffee & Tea, Food, Salad
# Hotels & Travel, Event Planning & Services, American (New), Italian, Hotels, Restaurants, Pizza, Breakfast & Brunch, Bars, Nightlife
# Food, Restaurants, Donuts
# Japanese, Sushi Bars, Restaurants
# Nightlife, Breweries, Restaurants, Food, Pizza, Beer Bar, Bars
# American (Traditional), Bars, Restaurants, Nightlife
# Food, Beer, Wine & Spirits, Specialty Food, Delis, Grocery, Restaurants
# Breakfast & Brunch, Food, Beer, Wine & Spirits, Bars, Seafood, Restaurants, Wine Bars, Cocktail Bars, American (New), Nightlife
# Restaurants, Sandwiches, Chicken Shop, Chicken Wings, Fast Food, Caterers, Event Planning & Services
# American (New), Mexican, Restaurants
# Restaurants, Grocery, Food, Delis, Beer, Wine & Spirits
# Bakeries, Food, Patisserie/Cake Shop, Cafes, Restaurants
# Steakhouses, Bars, Brewpubs, Breweries, American (Traditional), Nightlife, Sports Bars, Restaurants, Food, Burgers, Comfort Food, Seafood
# Cafes, Restaurants, American (Traditional), Cocktail Bars, Breakfast & Brunch, Food, Beer, Wine & Spirits, American (New), Bars, Nightlife
# Gelato, Food, Restaurants, Italian, Vegetarian, Gluten-Free
# Seafood, Food, Specialty Food, Meat Shops, Restaurants, Seafood Markets
# Delis, Nightlife, Bars, Food, Wine Bars, Restaurants, Coffee & Tea, Sandwiches, Wineries, Specialty Food, Arts & Entertainment, Cheese Shops
# Restaurants, Burgers
# Pizza, Restaurants, Italian
# Restaurants, Food, Mexican, Convenience Stores
# Restaurants, American (Traditional), Seafood, Breakfast & Brunch
# Sandwiches, Restaurants, American (New), Chinese, Delis, Cafes
# Nightlife, Seafood, Restaurants, Bars, Cocktail Bars, Burgers, Fish & Chips, Sandwiches
# Burgers, Fast Food, Restaurants
# Restaurants, Chinese, Szechuan, Soup, Seafood
# Restaurants, American (New), Delis, Breakfast & Brunch, Tapas/Small Plates, Cafes
# Restaurants, American (New), Seafood, Steakhouses
# Restaurants, Tacos, Mexican, Event Planning & Services, Food, Food Trucks, Caterers
# Fast Food, Restaurants, Pizza, Salad
# Restaurants, Cafes, Coffee & Tea, Food, Desserts
# American (New), Beer, Wine & Spirits, Food, Japanese, Bars, Asian Fusion, Ramen, Restaurants, Cocktail Bars, Nightlife
# Tacos, Mexican, Restaurants
# Restaurants, Asian Fusion, Breakfast & Brunch, American (Traditional)
# Breakfast & Brunch, American (New), Restaurants, American (Traditional), Nightlife, Bars
# Restaurants, Burgers, Fast Food
# Restaurants, Bars, Irish, Nightlife, Pubs, Gastropubs
# Mexican, Restaurants, Grocery, Food
# Coffee & Tea, Restaurants, Cafes, Food, Acai Bowls, Juice Bars & Smoothies
# Ethnic Food, Specialty Food, Local Flavor, Mexican, Restaurants, Food, Breakfast & Brunch, Fast Food, Juice Bars & Smoothies
# Thai, Vegetarian, Noodles, Restaurants, Asian Fusion
# Pakistani, Restaurants, Buffets, Seafood, Halal, Indian, Vegetarian, Vegan, Food, Salad, Desserts
# Fast Food, Delis, Sandwiches, Restaurants
# Beer Bar, Breakfast & Brunch, Vegan, Bars, Nightlife, Restaurants
# Restaurants, Breakfast & Brunch, Sandwiches, Coffee & Tea, Food
# Food, Restaurants, Bakeries, Desserts
# Restaurants, Fast Food, Pizza, Food Court, Hot Dogs
# Restaurants, Nightlife, Whiskey Bars, Japanese, Bars, Sushi Bars
# American (Traditional), American (New), French, Restaurants
# American (Traditional), Bakeries, Restaurants, Italian, Breakfast & Brunch, Food
# Soul Food, Wine Tasting Room, Food, Restaurants, Arts & Entertainment, Vegan, Mexican, American (Traditional), Nightlife, Wineries, Bars
# Vietnamese, Restaurants, Bars, Seafood, Wine Bars, Vegetarian, Nightlife, Noodles
# Restaurants, Indian, Himalayan/Nepalese
# Shopping Centers, Shopping, Restaurants
# Bars, American (New), Sandwiches, Nightlife, Beer Bar, Restaurants
# American (Traditional), Burgers, Restaurants, Sandwiches
# Restaurants, Italian, Asian Fusion, Breakfast & Brunch, Delis, American (New), American (Traditional)
# Pizza, Food, Restaurants, Bubble Tea, Sandwiches, Food Delivery Services
# American (Traditional), Restaurants
# Restaurants, Nightlife, Bars, Food, American (New), Piano Bars, Beer, Wine & Spirits, Cocktail Bars
# Restaurants, American (New), Sandwiches, Barbeque
# Mexican, Breakfast & Brunch, Restaurants, Seafood
# Pizza, Restaurants, Italian, Vegetarian
# Fast Food, Restaurants, Burgers
# Food, Restaurants, Florists, Flowers & Gifts, Bakeries, Health & Medical, Pharmacy, Shopping, Grocery, Drugstores
# Seafood, Cajun/Creole, American (New), Restaurants
# Restaurants, Food, Juice Bars & Smoothies, Breakfast & Brunch
# Sandwiches, Chinese, Cocktail Bars, Restaurants, Nightlife, Salad, Delis, Bars, Lounges
# Tapas Bars, Restaurants
# Sandwiches, Pop-Up Restaurants, American (Traditional), Restaurants, Burgers
# American (Traditional), Seafood, Sandwiches, Restaurants, Burgers, Breakfast & Brunch
# Cafeteria, Breakfast & Brunch, Sandwiches, Wraps, Restaurants, Cafes, Salad
# Restaurants, Event Planning & Services, Caterers, Pizza, Food Trucks, Food
# Chicken Shop, Desserts, Food, Breakfast & Brunch, Barbeque, Mexican, Bars, Nightlife, Cocktail Bars, Restaurants
# American (New), Restaurants, Salad, Burgers
# Food Trucks, Event Planning & Services, Mexican, Street Vendors, Caterers, Restaurants, Food
# Szechuan, Chinese, Restaurants
# Restaurants, Sushi Bars, Food, Specialty Food, Japanese
# American (New), Italian, Bars, Restaurants, Nightlife, Food, Beer, Wine & Spirits
# Restaurants, Hunting & Fishing Supplies, Delis, Sporting Goods, Automotive, Car Wash, Shopping
# Restaurants, Juice Bars & Smoothies, Food
# Restaurants, Tapas/Small Plates
# Restaurants, Fast Food, Sandwiches
# Burgers, Salad, Restaurants, Desserts, Food, Chicken Shop
# Nightlife, Bars, Gastropubs, Restaurants, American (New)
# Food, Specialty Food, Seafood, Cajun/Creole, Restaurants
# Specialty Food, Convenience Stores, Juice Bars & Smoothies, Health Markets, Restaurants, Food, Vegan, Ice Cream & Frozen Yogurt
# Delis, Sandwiches, Italian, Pizza, Restaurants
# Mediterranean, Restaurants, French, Breakfast & Brunch, American (New), Seafood, Buffets, Italian
# Hotels, Restaurants, Beauty & Spas, Hotels & Travel, Day Spas, Event Planning & Services
# Delis, Restaurants, Burgers, Sandwiches, Middle Eastern
# Restaurants, Sushi Bars, Japanese
# Tex-Mex, Tacos, Mexican, Restaurants, Fast Food, Breakfast & Brunch
# Coffee & Tea, Cafes, Restaurants, Food
# Vegan, Asian Fusion, Bubble Tea, Restaurants, Japanese, Mexican, Tacos, Vegetarian, Food
# Fast Food, Restaurants
# Sandwiches, Restaurants, Delis
# Restaurants, Vegetarian, Tex-Mex, Sandwiches
# American (New), Nightlife, Hotels, Event Planning & Services, Restaurants, Hotels & Travel, Bars
# Mexican, Restaurants, Fast Food
# Restaurants, Event Planning & Services, Caterers, Shopping, Arts & Crafts, Barbeque, Cooking Classes
# American (New), Restaurants, Bars, Nightlife, Burgers, Tapas/Small Plates
# Cafeteria, Cafes, American (New), Restaurants, Sandwiches, Pizza, Mexican
# American (Traditional), Restaurants, Burgers
# Bars, Cocktail Bars, American (Traditional), Restaurants, Nightlife
# Seafood, Restaurants, Italian, Nightlife, Bars, Wine Bars, Pizza
# American (New), Food, Restaurants, Coffee & Tea, Breakfast & Brunch
# Restaurants, Burgers, Food, Fast Food, Coffee & Tea
# Bars, American (Traditional), Gastropubs, Nightlife, Cocktail Bars, Restaurants, American (New)
# Mexican, Fast Food, Tex-Mex, Restaurants
# Restaurants, Nightlife, Burgers, American (Traditional), American (New), Fast Food, Sandwiches, Food Delivery Services, Food
# Salad, Restaurants, Event Planning & Services, Food Delivery Services, Personal Chefs, Caterers, Food
# Vegan, American (New), Restaurants
# Burgers, Ice Cream & Frozen Yogurt, American (New), Restaurants, Salad, Chicken Shop, Food
# Ethiopian, Soul Food, Restaurants, Comfort Food
# Nightlife, Seafood, American (Traditional), Bars, Restaurants
# Seafood, Bars, Wine Bars, American (New), Restaurants, French, Nightlife, Mexican
# Restaurants, Pop-Up Restaurants
# Nightlife, Gay Bars, Wine Bars, Bars, Cupcakes, Desserts, Tapas Bars, Beer Bar, Food, Restaurants
# Pop-up Shops, Wine Tasting Room, Shopping Centers, Restaurants, Shopping, Food, Beer, Wine & Spirits, Arts & Entertainment, Wineries, American (Traditional)
# Restaurants, New Mexican Cuisine, Mexican, Fast Food
# Restaurants, Bars, Nightlife, American (New), American (Traditional)
# Restaurants, American (New), French
# Restaurants, Sandwiches, Chicken Wings, Salad, Italian, Pizza
# Restaurants, Coffee & Tea, Food
# Restaurants, Mexican, Breakfast & Brunch
# Grocery, Restaurants, Specialty Food, Sandwiches, Food
# Food, American (New), Thai, Restaurants, Asian Fusion, Desserts, Cafes, Sandwiches, Caterers, Event Planning & Services
# Food, Grocery, Korean, Restaurants, International Grocery
# Salad, Beer, Wine & Spirits, Burgers, Ice Cream & Frozen Yogurt, Food, American (New), Restaurants, American (Traditional), Chicken Shop
# Specialty Food, Health Markets, Restaurants, Gluten-Free, Bakeries, Coffee & Tea, Desserts, Breakfast & Brunch, Food
# Italian, Cafes, Mediterranean, Restaurants
# Comfort Food, Asian Fusion, Chinese, Tapas/Small Plates, Noodles, Thai, Restaurants
# Restaurants, Food, Live/Raw Food, Juice Bars & Smoothies, Vegan
# Restaurants, Italian, Pizza
# Restaurants, Thai, Food, Chicken Wings, Ice Cream & Frozen Yogurt, Desserts
# Restaurants, Coffee & Tea, American (Traditional), Breakfast & Brunch, Food, Diners
# Restaurants, Vietnamese, Vegetarian
# Restaurants, Food, Bubble Tea
# Restaurants, Coffee & Tea, Gluten-Free, Juice Bars & Smoothies, Food
# Soup, Thai, Restaurants, Noodles
# Restaurants, Sandwiches, Breakfast & Brunch, Coffee & Tea, Food, Juice Bars & Smoothies
# Sandwiches, Salad, Bagels, Coffee & Tea, Breakfast & Brunch, Food, Restaurants
# Delis, Restaurants, Bagels, Bakeries, Juice Bars & Smoothies, Sandwiches, Food
# Restaurants, Wine Bars, Seafood, Bars, Nightlife, Chinese, Vegetarian, Dim Sum
# Nightlife, Restaurants, Steakhouses, Bars
# Juice Bars & Smoothies, American (Traditional), Food, Restaurants
# Mexican, Coffee & Tea, Food, Cocktail Bars, Nightlife, Event Planning & Services, Restaurants, Caterers, Wine Bars, Bars, Salad
# British, International Grocery, Grocery, Food, Ethnic Food, Herbal Shops, Restaurants, Health Markets, Specialty Food, Health & Medical
# Coffee & Tea, Food, Desserts, Turkish, Restaurants, Bakeries
# Restaurants, Middle Eastern, Bars, Nightlife, Mediterranean, Lebanese
# Sandwiches, Restaurants
# Food, Restaurants, Cafes, Coffee & Tea, Beer, Wine & Spirits, Pizza
# Restaurants, Seafood, Nightlife, Steakhouses, Bars, American (Traditional), Cocktail Bars, Wine Bars
# Burgers, Restaurants, Mexican
# Restaurants, Food, French, Coffee & Tea, Bakeries, Breakfast & Brunch
# Vietnamese, Restaurants, Noodles
# American (New), Breakfast & Brunch, Restaurants, Salad, Italian, Nightlife, Bars, Beer, Wine & Spirits, Sandwiches, Coffee & Tea, Wine Bars, Food, Pizza
# Restaurants, Ethiopian, French
# Nightlife, Restaurants, Sports Bars, Bars
# Food, Restaurants, Coffee & Tea
# French, Cafes, Restaurants, Breakfast & Brunch, Food, Sandwiches, Bakeries
# Donuts, Bakeries, Food, Restaurants, Coffee & Tea, Breakfast & Brunch
# Hot Dogs, Restaurants
# Restaurants, Convenience Stores, Food, Grocery
# Bars, Nightlife, Tapas/Small Plates, Tapas Bars, Restaurants, Lounges
# American (Traditional), Coffee & Tea, Breakfast & Brunch, Food, Bakeries, Restaurants
# Restaurants, Food, Breakfast & Brunch, Bakeries
# Pizza, Italian, Fast Food, Restaurants
# Restaurants, Breakfast & Brunch, Sandwiches, American (Traditional)
# Nightlife, Bars, Cocktail Bars, Food, American (New), Desserts, Restaurants
# Restaurants, Food, Desserts, Delis, Sandwiches
# Desserts, Gelato, Ice Cream & Frozen Yogurt, Food, Cafes, Restaurants
# Sandwiches, Salad, Restaurants, Soup, Vegetarian, Local Flavor, Delis
# Pop-Up Restaurants, Barbeque, Restaurants
# Bars, Tapas/Small Plates, Japanese, Nightlife, Restaurants, Sushi Bars, Cocktail Bars, Asian Fusion
# Juice Bars & Smoothies, Restaurants, Food, Vegan, Cafes, Bakeries, Coffee & Tea, Gluten-Free, Vegetarian, Acai Bowls
# Venues & Event Spaces, Cafes, Wine Bars, Event Planning & Services, Nightlife, Bars, Restaurants, American (New)
# Food, Breweries, Beer Gardens, Mediterranean, Nightlife, Restaurants
# Vegan, Vegetarian, Sandwiches, Restaurants
# Cocktail Bars, Farmers Market, Tapas Bars, Food, Desserts, Nightlife, Asian Fusion, Restaurants, Tapas/Small Plates, Bars, Indonesian
# Food, French, Cafes, Desserts, Bakeries, Restaurants, Breakfast & Brunch
# Breakfast & Brunch, Bocce Ball, Event Planning & Services, Beer, Wine & Spirits, Venues & Event Spaces, Italian, Active Life, Food, Wedding Planning, Restaurants
# Trivia Hosts, Nightlife, Sports Bars, Beer Gardens, Event Planning & Services, Restaurants, Bars, Beer Bar
# Fast Food, Burgers, Coffee & Tea, Restaurants, Food
# Salad, Restaurants, Tacos, Mexican, Breakfast & Brunch
# Restaurants, Sandwiches, Specialty Food, Pasta Shops, Grocery, Food, Ethnic Grocery, Delis
# Steakhouses, Cafes, American (Traditional), Seafood, Breakfast & Brunch, Restaurants, Sandwiches
# Restaurants, Tacos, Mexican
# Bakeries, Cafes, Coffee & Tea, Food, Desserts, Breakfast & Brunch, Restaurants
# Nightlife, Beer Gardens, Restaurants, Pizza, Hot Dogs
# Donuts, Restaurants, Food
# Event Planning & Services, Caterers, Sandwiches, Bars, Steakhouses, Delis, Nightlife, Burgers, Cafes, American (New), Restaurants, American (Traditional)
# Specialty Food, Beer, Wine & Spirits, Grocery, Bakeries, Restaurants, Delis, Butcher, Food
# Nightlife, American (Traditional), Cafes, Restaurants, Wine Bars, Breakfast & Brunch, Bars
# Restaurants, Latin American, Mexican, Tacos
# Restaurants, Hot Dogs
# Nightlife, Wine Bars, Bars, American (Traditional), Tapas/Small Plates, Tapas Bars, Food, Arts & Entertainment, Wine Tasting Room, Wineries, American (New), Restaurants
# Patisserie/Cake Shop, French, Food, Restaurants, Bakeries, Cupcakes
# Fast Food, Restaurants, Sandwiches
# Restaurants, Specialty Food, Do-It-Yourself Food, Seafood Markets, Food, Caterers, Seafood, Breakfast & Brunch, Event Planning & Services
# Chinese, Food, Dim Sum, Desserts, Coffee & Tea, Restaurants
# Fast Food, Breakfast & Brunch, Restaurants, Mexican, Tex-Mex, Tacos
# Restaurants, Vegan
# Food, Beer, Wine & Spirits, Hot Dogs, Restaurants
# Salad, Restaurants, Pizza, Sandwiches, Italian
# Modern European, Nightlife, Bars, Restaurants, Bakeries, Wine Bars, Food, Scandinavian, Breakfast & Brunch
# Restaurants, Gastropubs, Cocktail Bars, Bars, American (New), Nightlife, Beer Bar, American (Traditional)
# Indian, Food, Restaurants, Bubble Tea, Pakistani, Fast Food
# Vegan, Restaurants, Italian
# Chicken Wings, Restaurants, Fast Food, Chicken Shop
# Coffee & Tea, Food, Bagels, Breakfast & Brunch, Restaurants
# Seafood, American (Traditional), Breakfast & Brunch, Restaurants
# Restaurants, Food, Mexican, Bakeries
# Pizza, Nightlife, Italian, Restaurants, Bars
# Health Retreats, Venues & Event Spaces, Hotels & Travel, Restaurants, Event Planning & Services
# Restaurants, Japanese
# Food Trucks, Caterers, Seafood, Restaurants, Event Planning & Services, Food
# Pubs, Bars, Food, American (Traditional), American (New), Nightlife, Breweries, Brewpubs, Restaurants
# Hotels & Travel, Hotels, Event Planning & Services, Restaurants, Venues & Event Spaces, Resorts
# Caterers, Restaurants, Spanish, Personal Chefs, Event Planning & Services
# Restaurants, Bakeries, Cafes, Coffee & Tea, Food, Desserts
# Thai, Restaurants, Food, Donuts
# Bakeries, Sandwiches, Food, Restaurants, American (Traditional)
# Seafood, Restaurants, Hawaiian, American (New), Breakfast & Brunch
# American (Traditional), American (New), Nightlife, Bars, Beer Bar, Restaurants, Burgers
# Sandwiches, Restaurants, Delis, Breakfast & Brunch
# Restaurants, Cocktail Bars, Salad, Bars, Burgers, American (New), Nightlife, Barbeque
# Restaurants, Nightlife, American (New), Food, Farmers Market, Bars, Wine Bars
# Restaurants, Delis, Coffee & Tea, Breakfast & Brunch, Food, Gluten-Free, Cafes, Beer, Wine & Spirits
# Seafood, Restaurants, Breakfast & Brunch, Lounges, Cocktail Bars, Mediterranean, Bars, Tapas/Small Plates, American (New), Nightlife
# Caterers, Italian, Restaurants, Delis, Event Planning & Services
# Restaurants, Chinese, Vegetarian
# Breakfast & Brunch, Coffee & Tea, Bakeries, Desserts, Donuts, Food, Restaurants
# Japanese, Restaurants, Sushi Bars, Vegetarian
# Bubble Tea, Restaurants, Taiwanese, Coffee & Tea, Food
# Restaurants, Barbeque, Hawaiian
# Food, Local Flavor, Seafood, Arts & Entertainment, Shopping, Festivals, Restaurants, Arts & Crafts
# Restaurants, Fast Food, Sandwiches, Breakfast & Brunch
# Specialty Food, Grocery, Farmers Market, Shopping, Restaurants, Public Markets, Local Flavor, Food
# Event Planning & Services, Nightlife, Tapas Bars, Spanish, Modern European, Bars, Cocktail Bars, Seafood, Venues & Event Spaces, Restaurants
# Garage Door Services, Restaurants, Live/Raw Food, Food, Home Services, Mediterranean, Keys & Locksmiths, Burgers, Vegetarian, Juice Bars & Smoothies, Vegan, Salad
# Vegan, Vegetarian, Restaurants, Indian
# American (New), Pizza, Pubs, Nightlife, Bars, Restaurants, American (Traditional), Breakfast & Brunch, Beer Bar
# Caterers, Restaurants, Mexican, Event Planning & Services, Food, Tacos, Bartenders, Food Delivery Services
# Bars, Wine Bars, American (New), Nightlife, Restaurants
# Breakfast & Brunch, Fast Food, Tex-Mex, Restaurants, Mexican, Tacos
# American (New), American (Traditional), Bars, Restaurants, Salad, Burgers, Ice Cream & Frozen Yogurt, Food, Nightlife, Beer, Wine & Spirits, Beer Bar, Chicken Shop
# Bars, Mediterranean, Restaurants, Nightlife, Moroccan, Event Planning & Services, Venues & Event Spaces, Italian
# Delis, Gluten-Free, Fast Food, Salad, Sandwiches, Restaurants
# Event Planning & Services, Latin American, Caterers, Food, Restaurants, Empanadas, Argentine
# Restaurants, Sandwiches, Nightlife, Bars, American (New), Cocktail Bars
# Pizza, Wine Bars, Restaurants, Venues & Event Spaces, Sandwiches, Cocktail Bars, American (New), Event Planning & Services, Burgers, Bars, Nightlife, Beer Bar
# Salad, Restaurants, Vegetarian, Chicken Shop, Chicken Wings, Sandwiches, Nightlife
# Restaurants, Pizza, Sandwiches, Chicken Wings
# Restaurants, Coffee & Tea, Breakfast & Brunch, Gluten-Free, Food, Sandwiches, Bagels
# Restaurants, Nightlife, Hotels & Travel, Hotels, Italian, Event Planning & Services
# Mexican, Restaurants, Fish & Chips
# Japanese, Restaurants, Noodles, Sushi Bars
# Bakeries, Vegan, Specialty Food, Food Delivery Services, Food, Coffee & Tea, Gluten-Free, Farmers Market, Restaurants, Organic Stores
# Restaurants, Japanese, Ramen
# Restaurants, Burgers, Food, Ice Cream & Frozen Yogurt, American (Traditional), Salad

# %%
# Identificamos los servicios unicos en el total de filas
categorias_unicas = df_restaurantes_CA['categories'].unique()
KTunicas = []

for categoria in categorias_unicas:
    unique_values = set(categoria.split(', '))
    KTunicas.extend(unique_values)

KTunicas = list(set(KTunicas))

print(KTunicas)
# Out:
# ['Brewpubs', 'Nail Salons', 'Religious Organizations', 'Wine Bars', 'Ethnic Grocery', 'Tex-Mex', 'Brazilian', 'Pasta Shops', 'Bars', 'Imported Food', 'Bubble Tea', 'Pop-Up Restaurants', 'Arcades', 'Home Services', 'Home & Garden', 'Restaurants', 'Caterers', 'Chinese', 'Street Vendors', 'Cocktail Bars', 'Public Markets', 'Cuban', 'Beer Gardens', 'Lounges', 'Hotels & Travel', 'Health Retreats', 'Gastropubs', 'Cooking Classes', 'Pest Control', 'Tasting Classes', 'Cosmetics & Beauty Supply', 'Personal Chefs', 'Flowers & Gifts', 'Wine Tours', 'Desserts', 'Herbal Shops', 'Tea Rooms', 'Coffee Roasteries', 'Cosmetic Surgeons', 'Organic Stores', 'Florists', 'Halal', 'Convenience Stores', 'Australian', 'Specialty Schools', 'Fish & Chips', 'Tacos', 'Wraps', 'Accessories', 'Pet Stores', 'Venues & Event Spaces', 'Taiwanese', 'Breakfast & Brunch', 'Chicken Wings', 'Food Delivery Services', 'Local Services', 'Patisserie/Cake Shop', 'Day Spas', 'Falafel', 'Spanish', 'Garage Door Services', 'Chiropractors', 'Speakeasies', 'Landmarks & Historical Buildings', 'Cooking Schools', 'Shopping', 'Nightlife', 'Bagels', 'Bocce Ball', 'Greek', 'Music Venues', 'Mediterranean', 'Education', 'Wine Tasting Classes', 'Trivia Hosts', 'Jazz & Blues', 'Gluten-Free', 'Acai Bowls', 'Wildlife Control', 'Juice Bars & Smoothies', 'Themed Cafes', 'Home Decor', 'Pet Adoption', 'Food', 'Dim Sum', 'Seafood Markets', 'French', 'Pakistani', 'Cupcakes', 'Shaved Ice', 'Grocery', 'Sushi Bars', 'Japanese', 'Dance Clubs', 'Soup', 'Chicken Shop', 'Pizza', 'Tours', 'Gay Bars', 'Hot Dogs', 'Soul Food', 'Cheese Shops', 'Resorts', 'International Grocery', 'Donuts', 'Asian Fusion', 'Whiskey Bars', 'Art Galleries', 'Modern European', 'Pets', 'Scandinavian', 'Party & Event Planning', 'Beer Bar', 'Ramen', 'Hunting & Fishing Supplies', 'Local Flavor', 'British', 'Food Stands', 'Irish', 'Poke', 'Arts & Crafts', 'Boat Tours', 'Vegan', 'Italian', 'Coffee & Tea', 'Hotels', 'Walking Tours', 'Creperies', 'Pubs', 'Food Trucks', 'Noodles', 'American (Traditional)', 'Churches', 'Wineries', 'Do-It-Yourself Food', 'Empanadas', 'Doctors', 'Cafes', 'Bakeries', 'Festivals', 'Fast Food', 'Cajun/Creole', 'Vietnamese', 'Shopping Centers', 'Tapas Bars', 'Pet Services', 'Steakhouses', 'Fruits & Veggies', 'Keys & Locksmiths', 'Wine Tasting Room', 'Beauty & Spas', 'Barbeque', 'Boating', 'Delis', 'Butcher', 'Automotive', 'Champagne Bars', 'Szechuan', 'Health Markets', 'Thai', 'Diners', "Women's Clothing", 'Hawaiian', 'Lebanese', 'Drugstores', 'Mexican', 'Argentine', 'Tabletop Games', 'Salad', 'Beer', 'Fashion', 'Pet Sitting', 'Food Court', 'Sports Bars', 'Hot Pot', 'Salvadoran', 'Farmers Market', 'Buffets', 'Sporting Goods', 'Middle Eastern', 'Indonesian', 'Meat Shops', 'Gelato', 'Arts & Entertainment', 'Ice Cream & Frozen Yogurt', 'New Mexican Cuisine', 'Burgers', 'Tapas/Small Plates', 'Health & Medical', 'Active Life', 'Live/Raw Food', 'American (New)', 'Honey', 'Cafeteria', 'Food Tours', 'Ethiopian', 'Turkish', 'Bartenders', 'Breweries', 'Bowling', 'Tuscan', 'Massage', 'Moroccan', 'Car Wash', 'Korean', 'Piano Bars', 'Himalayan/Nepalese', 'Event Planning & Services', 'Pharmacy', 'Latin American', 'Indian', 'Ethnic Food', 'Sandwiches', 'Cannabis Clinics', 'Pop-up Shops', 'Social Clubs', 'Golf', 'Vegetarian', 'Souvenir Shops', 'Public Services & Government', 'Specialty Food', 'Seafood', 'Wine & Spirits', 'Wedding Planning', 'Karaoke', 'Comfort Food']

# %%
# Validamos si existen las categorias de estilos de cocina que nos interesan, dentro del total del dataset

categorias_interes = [
"American","American (Traditional)","American (New)","Argentine",
"Asian Fusion","Brazilian", "British","Caribbean","Chilean",
"Colombian","Cuban","Dominican","French","Hawaiian","Indian",
"Italian","Japanese","Korean","Latin American","Lebanese",
"Mediterranean","Mexican","MiddleEastern","Moroccan",
"Peruvian","Puerto Rican","Salvadoran","Scandinavian",
"Spanish","Thai","Turkish","Venezuelan","Vietnamese"
] 

result = {}

for categoria in categorias_interes:
    result[categoria] = False

index_list = []

for item in KTunicas:
    subcategories = item.split(',')
    for subcategoria in subcategories:
        subcategoria = subcategoria.strip()
        if subcategoria in categorias_interes:
            result[subcategoria] = True
            index_list.append(1)

print("No".ljust(10) + "| Servicios_CA".ljust(20) + "          | Encontrados")
print("-" * 61)

index = 0
for categoria, found in result.items():
    if found:
        index += index_list[0]
        index_list.pop(0)
        print(f"{index:<10}| {categoria.ljust(28)}| {found}")
# Out:
# No        | Servicios_CA                | Encontrados
# -------------------------------------------------------------
# 1         | American (Traditional)      | True
# 2         | American (New)              | True
# 3         | Argentine                   | True
# 4         | Asian Fusion                | True
# 5         | Brazilian                   | True
# 6         | British                     | True
# 7         | Cuban                       | True
# 8         | French                      | True
# 9         | Hawaiian                    | True
# 10        | Indian                      | True
# 11        | Italian                     | True
# 12        | Japanese                    | True
# 13        | Korean                      | True
# 14        | Latin American              | True
# 15        | Lebanese                    | True
# 16        | Mediterranean               | True
# 17        | Mexican                     | True
# 18        | Moroccan                    | True
# 19        | Salvadoran                  | True
# 20        | Scandinavian                | True
# 21        | Spanish                     | True
# 22        | Thai                        | True
# 23        | Turkish                     | True
# 24        | Vietnamese                  | True

# %%
categorias_interes = [
"American","American (Traditional)","American (New)","Argentine",
"Asian Fusion","Brazilian", "British","Caribbean","Chilean",
"Colombian","Cuban","Dominican","French","Hawaiian","Indian",
"Italian","Japanese","Korean","Latin American","Lebanese",
"Mediterranean","Mexican","MiddleEastern","Moroccan",
"Peruvian","Puerto Rican","Salvadoran","Scandinavian",
"Spanish","Thai","Turkish","Venezuelan","Vietnamese"
] 

# Convertir la columna 'categories' a minúsculas y realizar la búsqueda para cada palabra clave
condiciones = [df_restaurantes_CA['categories'].str.lower().str.contains(palabra.lower()) for palabra in categorias_interes]

# Obtener el DataFrame filtrado
df_filtrado = df_restaurantes_CA[pd.concat(condiciones, axis=1).any(axis=1)]

# Imprimir el DataFrame filtrado
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 396 entries, 3 to 670
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   396 non-null    object
#  1   name          396 non-null    object
#  2   address       396 non-null    object
#  3   city          396 non-null    object
#  4   postal_code   396 non-null    object
#  5   latitude      396 non-null    object
#  6   longitude     396 non-null    object
#  7   stars         396 non-null    object
#  8   review_count  396 non-null    object
#  9   attributes    393 non-null    object
#  10  categories    396 non-null    object
#  11  hours         380 non-null    object
# dtypes: object(12)
# memory usage: 40.2+ KB

# %%
categorias_unicas = df_filtrado['categories'].unique()
for categoria in categorias_unicas:
    print(categoria)
# Out:
# Burgers, Cafes, Restaurants, Mexican, American (Traditional)
# Food, Restaurants, Chinese, Bubble Tea, Vietnamese
# Chicken Wings, Salad, Restaurants, Pizza, Italian, Sandwiches
# Restaurants, Thai
# Chinese, Restaurants, Asian Fusion, Szechuan
# Food, Vietnamese, Restaurants, Bubble Tea
# American (Traditional), Vegetarian, Restaurants
# Thai, Restaurants
# Restaurants, Soup, Salad, Thai
# American (Traditional), Restaurants, Seafood, Burgers, Tacos, Sandwiches, Mexican, Bars, Food, Beer Bar, Juice Bars & Smoothies, Nightlife
# Bars, Burgers, Restaurants, Nightlife, Sports Bars, American (New)
# Mexican, Restaurants, Food Trucks, Food
# Mexican, Arts & Entertainment, Festivals, Restaurants, Religious Organizations, Churches
# Restaurants, Fast Food, Mexican, Tacos, Burgers, Breakfast & Brunch
# Restaurants, American (Traditional), Food Delivery Services, Caterers, Venues & Event Spaces, Cocktail Bars, Bars, Wedding Planning, Nightlife, Food, Event Planning & Services
# Sushi Bars, Caterers, Food, Fast Food, Event Planning & Services, Japanese, Food Delivery Services, Korean, Restaurants, Specialty Food, Asian Fusion
# Mexican, Restaurants, Breakfast & Brunch
# American (Traditional), Vegan, Restaurants
# Tapas Bars, Nightlife, Salad, Restaurants, Cocktail Bars, Bars, Wine Bars, Cafes, Pizza, American (New)
# Seafood, Venues & Event Spaces, Cocktail Bars, Restaurants, Nightlife, Breakfast & Brunch, American (Traditional), Event Planning & Services, Bars, American (New)
# Food, Vegetarian, Salad, Restaurants, Cafes, American (Traditional), Burgers, Juice Bars & Smoothies
# Restaurants, Asian Fusion, Seafood, Sushi Bars, Japanese
# American (Traditional), Restaurants, Bars, Nightlife
# Mexican, Tacos, Restaurants
# Restaurants, American (Traditional), Nightlife, Bars, Cocktail Bars
# Mexican, Restaurants, Bakeries, Food, Sandwiches, Coffee & Tea
# Japanese, Restaurants, Asian Fusion, Fast Food
# Sushi Bars, Japanese, Restaurants
# Coffee & Tea, Breakfast & Brunch, Restaurants, American (New), Food
# Chicken Wings, Restaurants, Beer, Wine & Spirits, Sandwiches, Food, Pizza, Italian
# Mexican, Restaurants
# Health Markets, Coffee & Tea, Ice Cream & Frozen Yogurt, Restaurants, Juice Bars & Smoothies, Breakfast & Brunch, Food, American (New), Specialty Food
# Restaurants, Japanese, Sushi Bars
# Restaurants, Mexican
# Event Planning & Services, Restaurants, Nightlife, Caterers, Italian, Bars
# American (Traditional), Breakfast & Brunch, Restaurants, American (New), Burgers
# Coffee & Tea, Noodles, Restaurants, Seafood, Japanese, Ramen, Food, Asian Fusion, Poke
# Restaurants, Food, American (New), Beer, Wine & Spirits
# Breakfast & Brunch, Burgers, American (Traditional), American (New), Restaurants
# Restaurants, Nightlife, Japanese, Bars
# Food, Italian, Restaurants
# Thai, Restaurants, American (New), Pop-Up Restaurants, Asian Fusion
# Japanese, Restaurants, Steakhouses, Asian Fusion
# Steakhouses, Sushi Bars, Restaurants, Japanese
# American (Traditional), Restaurants, Shopping Centers, Shopping, Local Flavor
# Restaurants, Barbeque, Mexican
# Bars, Restaurants, Nightlife, Sandwiches, American (New), Tapas Bars, Wine Bars
# Restaurants, American (Traditional), Lounges, Nightlife, Bars, Burgers, American (New)
# Restaurants, American (Traditional), American (New), Salad, Pizza, Gluten-Free
# Sandwiches, Restaurants, American (New)
# Bubble Tea, Restaurants, Food, Asian Fusion, Vegan, Acai Bowls
# American (Traditional), Restaurants, Wine Bars, Pizza, Cocktail Bars, Bars, Vegan, Nightlife
# Food, Bubble Tea, Chinese, Restaurants, Asian Fusion, Hot Pot
# Restaurants, Mexican, Fast Food
# Food Trucks, Food, Restaurants, Mexican
# Mexican, American (Traditional), Burgers, Restaurants
# Farmers Market, American (Traditional), American (New), Food, Restaurants
# Bakeries, Restaurants, Delis, Grocery, Specialty Food, Health Markets, Beer, Wine & Spirits, Food, American (New)
# Bars, Mexican, Nightlife, Restaurants
# Nightlife, Arts & Entertainment, Restaurants, Dance Clubs, Bars, Music Venues, Mexican, Sports Bars
# Restaurants, Asian Fusion, Food, Poke, Hawaiian, Seafood
# American (Traditional), Restaurants, Bars, Cocktail Bars, Nightlife, American (New), Sandwiches
# Restaurants, Seafood, American (New), Steakhouses
# Comfort Food, Bubble Tea, Restaurants, Tea Rooms, Asian Fusion, Coffee & Tea, Food
# Restaurants, American (New), Barbeque, Food, Sandwiches, Wine Bars, Diners, Bars, Specialty Food, American (Traditional), Nightlife
# Tapas/Small Plates, Restaurants, Breakfast & Brunch, Seafood, American (New)
# Mexican, Tacos, Restaurants, Barbeque, Food Delivery Services, Food Trucks, Food, Event Planning & Services, Caterers
# Restaurants, Vegetarian, Salad, Coffee & Tea, Tex-Mex, American (Traditional), Burgers, Food, Sandwiches, Mexican, Juice Bars & Smoothies
# Pizza, Nightlife, Italian, Bars, Restaurants, Wine Bars
# Lounges, American (New), Burgers, Cocktail Bars, Bars, Sports Bars, Nightlife, Restaurants
# Comfort Food, Bakeries, Food, Desserts, Restaurants, Empanadas, Argentine
# Latin American, Restaurants, Argentine, Empanadas, Food
# Japanese, Restaurants, Beer, Wine & Spirits, Food, Sushi Bars
# Noodles, Restaurants, Gluten-Free, Creperies, Chinese, Asian Fusion
# Food, Asian Fusion, Bubble Tea, Restaurants, Japanese
# American (New), Food, Specialty Food, Restaurants
# Food, Restaurants, Bakeries, Mexican, Breakfast & Brunch
# Delis, Restaurants, Grocery, American (New), Cafes, Coffee & Tea, Beer, Wine & Spirits, Food
# Restaurants, American (New), Seafood, Italian, Pizza
# Juice Bars & Smoothies, Breakfast & Brunch, Brazilian, Restaurants, Food, Salad, Acai Bowls
# Sushi Bars, Restaurants, Japanese
# Breakfast & Brunch, Diners, Nightlife, Restaurants, Comfort Food, American (New), Burgers, Salad
# Food, Mexican, Restaurants, Seafood, Desserts
# Restaurants, Fish & Chips, Food, Seafood, American (Traditional), Fast Food, Coffee & Tea, Breakfast & Brunch
# Restaurants, Italian
# Restaurants, American (New), Italian, Breakfast & Brunch, Seafood
# Coffee & Tea, Breakfast & Brunch, Restaurants, French, Salad, Sandwiches, Desserts, Bakeries, Food
# Restaurants, Sandwiches, American (New)
# Tacos, Restaurants, Mexican
# Food Trucks, Tacos, Mexican, Salad, Food, Restaurants
# Restaurants, Salad, Sandwiches, Italian, Pizza
# Food, Mexican, Restaurants, Bakeries
# Gluten-Free, American (New), Restaurants, Sandwiches, Salad, Steakhouses, Delis, American (Traditional)
# Seafood, American (New), Salad, Restaurants, Sandwiches
# Seafood, Breakfast & Brunch, American (Traditional), Restaurants, Burgers
# Mediterranean, Restaurants, Salad, Greek
# Delis, Salad, Restaurants, Sandwiches, Burgers, American (Traditional)
# Ramen, Vegetarian, Sushi Bars, Japanese, Restaurants
# Cafes, Burgers, American (Traditional), Tacos, Seafood, Restaurants, Mexican
# Restaurants, Food, Breweries, American (Traditional), Brewpubs
# Ethnic Food, Restaurants, Mexican, Specialty Food, Imported Food, Food
# Asian Fusion, Poke, Seafood, Food, Restaurants
# Restaurants, American (Traditional)
# Restaurants, Mexican, Food, Beer, Wine & Spirits
# Restaurants, American (Traditional), Active Life, Golf
# Pop-Up Restaurants, Korean, Restaurants, Asian Fusion
# Breakfast & Brunch, Diners, Restaurants, American (Traditional)
# Latin American, Restaurants, Mexican, New Mexican Cuisine
# Restaurants, Breakfast & Brunch, American (Traditional)
# Sandwiches, Pizza, Restaurants, Italian
# Restaurants, American (Traditional), Breakfast & Brunch
# Italian, Restaurants
# Food, Live/Raw Food, Restaurants, Ice Cream & Frozen Yogurt, Asian Fusion, Poke, Seafood, Food Delivery Services
# Restaurants, Sushi Bars, Japanese, Asian Fusion
# Restaurants, Pizza, Italian
# Lounges, Art Galleries, American (New), Bars, Shopping, Nightlife, Restaurants, Music Venues, Gastropubs, Cocktail Bars, Arts & Entertainment
# Seafood, Restaurants, American (Traditional)
# Restaurants, Bars, Breakfast & Brunch, American (Traditional), Nightlife
# Food, Restaurants, Mediterranean, Farmers Market, Specialty Food, Organic Stores, Street Vendors
# Farmers Market, Food, Fast Food, American (New), Bars, Wine Bars, Breakfast & Brunch, Cafes, Restaurants, Nightlife
# Ramen, Japanese, Restaurants
# Wine Bars, Restaurants, Indian, Australian, Bars, American (New), Nightlife
# Restaurants, American (New)
# American (New), Food, Restaurants, American (Traditional)
# Gluten-Free, Gastropubs, Vegan, Restaurants, Indian
# Tuscan, Seafood, Wine Bars, Restaurants, Bars, Nightlife, Italian
# Steakhouses, American (Traditional), Desserts, Food, Restaurants
# Tex-Mex, Restaurants, Bars, American (Traditional), Nightlife
# French, American (New), Restaurants, Italian
# Restaurants, American (New), Mexican
# Restaurants, Breakfast & Brunch, American (Traditional), Burgers
# Restaurants, Tapas/Small Plates, Bars, Cocktail Bars, American (New), Italian, Vegetarian, Nightlife
# Breakfast & Brunch, Restaurants, Mexican, American (Traditional)
# Sandwiches, Restaurants, American (Traditional), Beer, Wine & Spirits, Chicken Shop, Food, American (New), Burgers
# Restaurants, Fast Food, Tacos, Breakfast & Brunch, Burgers, Mexican
# Tex-Mex, Tacos, Restaurants, Fast Food, Breakfast & Brunch, Mexican
# American (New), Wraps, Chinese, Sushi Bars, Barbeque, Dim Sum, Asian Fusion, Ramen, Restaurants, Noodles, Soup, Japanese, Hot Pot
# Mexican, Restaurants, Breakfast & Brunch, Seafood
# Food, Food Delivery Services, Restaurants, Mexican
# American (Traditional), American (New), Breakfast & Brunch, Restaurants, Seafood, Vegetarian, Nightlife, Event Planning & Services, Bars, Venues & Event Spaces
# Cafes, Restaurants, Sandwiches, Chicken Shop, Salad, American (New), Burgers, Breakfast & Brunch
# Restaurants, Mexican, Salad
# Seafood, American (New), Sandwiches, Steakhouses, Restaurants, Bars, Nightlife
# Mexican, Bars, Tex-Mex, Nightlife, Dance Clubs, Sports Bars, Restaurants
# Wineries, Food, Breweries, Nightlife, Bars, Arts & Entertainment, Champagne Bars, Pubs, American (New), Brewpubs, Restaurants
# Health & Medical, Restaurants, Mexican, Cannabis Clinics, Barbeque
# Italian, Salad, Pizza, Restaurants, Sandwiches
# Restaurants, Burgers, Sandwiches, Pizza, American (Traditional), Breakfast & Brunch
# Chicken Shop, Korean, Chicken Wings, Fast Food, American (New), Soul Food, Restaurants
# Restaurants, American (New), Breakfast & Brunch, Diners
# Restaurants, Nightlife, Mexican, Bars, Cocktail Bars
# Breweries, American (New), Arts & Entertainment, Music Venues, Restaurants, Brewpubs, Food, Nightlife
# Seafood, Nightlife, Hotels, Event Planning & Services, American (New), Bars, Diners, Restaurants, Hotels & Travel, Breakfast & Brunch
# Restaurants, Fish & Chips, Food, Specialty Food, Seafood Markets, American (Traditional), Seafood
# Pizza, Italian, Restaurants
# Bars, Mediterranean, Burgers, Restaurants, Gastropubs, Nightlife, Whiskey Bars, Cocktail Bars
# Restaurants, Tex-Mex, Fast Food, Mexican, Tacos
# Restaurants, American (New), Bars, Nightlife, Seafood, Breakfast & Brunch, American (Traditional), Desserts, Food
# Salad, American (New), Restaurants, Tacos, Mexican
# Korean, Barbeque, Restaurants
# Mexican, Gluten-Free, Latin American, Restaurants, Salvadoran, Caterers, Event Planning & Services
# Restaurants, Food, American (New), Wine Bars, Nightlife, Venues & Event Spaces, Bars, Event Planning & Services
# Sandwiches, Breakfast & Brunch, Restaurants, American (Traditional)
# Bakeries, Restaurants, Food, American (Traditional), Breakfast & Brunch, Coffee & Tea
# Food, Vietnamese, Restaurants, Noodles
# Restaurants, Beauty & Spas, American (New), Event Planning & Services, Hotels, Massage, Resorts, Day Spas, Hotels & Travel, Venues & Event Spaces
# Vietnamese, Pizza, Breakfast & Brunch, Restaurants, Gluten-Free
# Pizza, Restaurants, Italian, Vegan, Gluten-Free, Sandwiches
# Restaurants, Bars, Caterers, Mexican, Salad, Event Planning & Services, Desserts, Food, Nightlife
# Italian, Restaurants, American (New), Mediterranean
# American (New), Tapas/Small Plates, Event Planning & Services, Venues & Event Spaces, Restaurants, Burgers
# Food, Fast Food, Restaurants, Burgers, American (Traditional), Coffee & Tea
# Cocktail Bars, Bars, Restaurants, Breakfast & Brunch, Nightlife, Seafood, Cuban
# American (Traditional), Event Planning & Services, Caterers, Restaurants, American (New), Cafes, Sandwiches, Breakfast & Brunch
# Restaurants, Fast Food, Mexican, Burgers, Tacos, Breakfast & Brunch
# Szechuan, Chinese, Nightlife, Karaoke, Asian Fusion, Restaurants
# Restaurants, Event Planning & Services, American (Traditional), Venues & Event Spaces
# Delis, Sandwiches, American (New), Restaurants
# American (Traditional), Restaurants, Cafes, Coffee & Tea, Food
# Restaurants, Breakfast & Brunch, Latin American, Mexican, Seafood
# Burgers, American (New), Diners, Breakfast & Brunch, Fish & Chips, Restaurants
# Bakeries, Mexican, Restaurants, Food
# Restaurants, Breakfast & Brunch, American (New), American (Traditional), Burgers
# Mediterranean, Bars, Restaurants, Nightlife
# Restaurants, Nightlife, Mexican, Bars, Breakfast & Brunch
# Music Venues, Bars, Nightlife, Arts & Entertainment, Restaurants, American (Traditional)
# Korean, Restaurants, American (New), Mexican, Tacos, Nightlife, Fast Food, Bars
# Food, Italian, Pizza, Fast Food, Gelato, Chicken Wings, Sandwiches, Salad, Restaurants
# Restaurants, Vegan, Gluten-Free, Falafel, Mediterranean, Salad, Sandwiches
# Restaurants, American (Traditional), Barbeque, Steakhouses, Sandwiches
# Lounges, Karaoke, American (New), Mexican, Sports Bars, Tacos, Restaurants, Pizza, Bars, Nightlife, Food, Beer, Wine & Spirits
# Bars, Tacos, Mexican, Food, Beer, Wine & Spirits, Beer Bar, Nightlife, Restaurants
# Mexican, Restaurants, Desserts, Food
# Diners, Salad, American (Traditional), Breakfast & Brunch, Restaurants
# Caterers, Italian, Food Delivery Services, American (New), Event Planning & Services, Restaurants, Food
# Restaurants, Desserts, Sandwiches, Food, Italian
# Hotels & Travel, Event Planning & Services, American (New), Italian, Hotels, Restaurants, Pizza, Breakfast & Brunch, Bars, Nightlife
# Japanese, Sushi Bars, Restaurants
# American (Traditional), Bars, Restaurants, Nightlife
# Breakfast & Brunch, Food, Beer, Wine & Spirits, Bars, Seafood, Restaurants, Wine Bars, Cocktail Bars, American (New), Nightlife
# American (New), Mexican, Restaurants
# Steakhouses, Bars, Brewpubs, Breweries, American (Traditional), Nightlife, Sports Bars, Restaurants, Food, Burgers, Comfort Food, Seafood
# Cafes, Restaurants, American (Traditional), Cocktail Bars, Breakfast & Brunch, Food, Beer, Wine & Spirits, American (New), Bars, Nightlife
# Gelato, Food, Restaurants, Italian, Vegetarian, Gluten-Free
# Pizza, Restaurants, Italian
# Restaurants, Food, Mexican, Convenience Stores
# Restaurants, American (Traditional), Seafood, Breakfast & Brunch
# Sandwiches, Restaurants, American (New), Chinese, Delis, Cafes
# Restaurants, American (New), Delis, Breakfast & Brunch, Tapas/Small Plates, Cafes
# Restaurants, American (New), Seafood, Steakhouses
# Restaurants, Tacos, Mexican, Event Planning & Services, Food, Food Trucks, Caterers
# American (New), Beer, Wine & Spirits, Food, Japanese, Bars, Asian Fusion, Ramen, Restaurants, Cocktail Bars, Nightlife
# Tacos, Mexican, Restaurants
# Restaurants, Asian Fusion, Breakfast & Brunch, American (Traditional)
# Breakfast & Brunch, American (New), Restaurants, American (Traditional), Nightlife, Bars
# Mexican, Restaurants, Grocery, Food
# Ethnic Food, Specialty Food, Local Flavor, Mexican, Restaurants, Food, Breakfast & Brunch, Fast Food, Juice Bars & Smoothies
# Thai, Vegetarian, Noodles, Restaurants, Asian Fusion
# Pakistani, Restaurants, Buffets, Seafood, Halal, Indian, Vegetarian, Vegan, Food, Salad, Desserts
# Restaurants, Nightlife, Whiskey Bars, Japanese, Bars, Sushi Bars
# American (Traditional), American (New), French, Restaurants
# American (Traditional), Bakeries, Restaurants, Italian, Breakfast & Brunch, Food
# Soul Food, Wine Tasting Room, Food, Restaurants, Arts & Entertainment, Vegan, Mexican, American (Traditional), Nightlife, Wineries, Bars
# Vietnamese, Restaurants, Bars, Seafood, Wine Bars, Vegetarian, Nightlife, Noodles
# Restaurants, Indian, Himalayan/Nepalese
# Bars, American (New), Sandwiches, Nightlife, Beer Bar, Restaurants
# American (Traditional), Burgers, Restaurants, Sandwiches
# Restaurants, Italian, Asian Fusion, Breakfast & Brunch, Delis, American (New), American (Traditional)
# American (Traditional), Restaurants
# Restaurants, Nightlife, Bars, Food, American (New), Piano Bars, Beer, Wine & Spirits, Cocktail Bars
# Restaurants, American (New), Sandwiches, Barbeque
# Mexican, Breakfast & Brunch, Restaurants, Seafood
# Pizza, Restaurants, Italian, Vegetarian
# Seafood, Cajun/Creole, American (New), Restaurants
# Sandwiches, Pop-Up Restaurants, American (Traditional), Restaurants, Burgers
# American (Traditional), Seafood, Sandwiches, Restaurants, Burgers, Breakfast & Brunch
# Chicken Shop, Desserts, Food, Breakfast & Brunch, Barbeque, Mexican, Bars, Nightlife, Cocktail Bars, Restaurants
# American (New), Restaurants, Salad, Burgers
# Food Trucks, Event Planning & Services, Mexican, Street Vendors, Caterers, Restaurants, Food
# Restaurants, Sushi Bars, Food, Specialty Food, Japanese
# American (New), Italian, Bars, Restaurants, Nightlife, Food, Beer, Wine & Spirits
# Nightlife, Bars, Gastropubs, Restaurants, American (New)
# Delis, Sandwiches, Italian, Pizza, Restaurants
# Mediterranean, Restaurants, French, Breakfast & Brunch, American (New), Seafood, Buffets, Italian
# Restaurants, Sushi Bars, Japanese
# Tex-Mex, Tacos, Mexican, Restaurants, Fast Food, Breakfast & Brunch
# Vegan, Asian Fusion, Bubble Tea, Restaurants, Japanese, Mexican, Tacos, Vegetarian, Food
# American (New), Nightlife, Hotels, Event Planning & Services, Restaurants, Hotels & Travel, Bars
# Mexican, Restaurants, Fast Food
# American (New), Restaurants, Bars, Nightlife, Burgers, Tapas/Small Plates
# Cafeteria, Cafes, American (New), Restaurants, Sandwiches, Pizza, Mexican
# American (Traditional), Restaurants, Burgers
# Bars, Cocktail Bars, American (Traditional), Restaurants, Nightlife
# Seafood, Restaurants, Italian, Nightlife, Bars, Wine Bars, Pizza
# American (New), Food, Restaurants, Coffee & Tea, Breakfast & Brunch
# Bars, American (Traditional), Gastropubs, Nightlife, Cocktail Bars, Restaurants, American (New)
# Mexican, Fast Food, Tex-Mex, Restaurants
# Restaurants, Nightlife, Burgers, American (Traditional), American (New), Fast Food, Sandwiches, Food Delivery Services, Food
# Vegan, American (New), Restaurants
# Burgers, Ice Cream & Frozen Yogurt, American (New), Restaurants, Salad, Chicken Shop, Food
# Nightlife, Seafood, American (Traditional), Bars, Restaurants
# Seafood, Bars, Wine Bars, American (New), Restaurants, French, Nightlife, Mexican
# Pop-up Shops, Wine Tasting Room, Shopping Centers, Restaurants, Shopping, Food, Beer, Wine & Spirits, Arts & Entertainment, Wineries, American (Traditional)
# Restaurants, New Mexican Cuisine, Mexican, Fast Food
# Restaurants, Bars, Nightlife, American (New), American (Traditional)
# Restaurants, American (New), French
# Restaurants, Sandwiches, Chicken Wings, Salad, Italian, Pizza
# Restaurants, Mexican, Breakfast & Brunch
# Food, American (New), Thai, Restaurants, Asian Fusion, Desserts, Cafes, Sandwiches, Caterers, Event Planning & Services
# Food, Grocery, Korean, Restaurants, International Grocery
# Salad, Beer, Wine & Spirits, Burgers, Ice Cream & Frozen Yogurt, Food, American (New), Restaurants, American (Traditional), Chicken Shop
# Italian, Cafes, Mediterranean, Restaurants
# Comfort Food, Asian Fusion, Chinese, Tapas/Small Plates, Noodles, Thai, Restaurants
# Restaurants, Italian, Pizza
# Restaurants, Thai, Food, Chicken Wings, Ice Cream & Frozen Yogurt, Desserts
# Restaurants, Coffee & Tea, American (Traditional), Breakfast & Brunch, Food, Diners
# Restaurants, Vietnamese, Vegetarian
# Soup, Thai, Restaurants, Noodles
# Juice Bars & Smoothies, American (Traditional), Food, Restaurants
# Mexican, Coffee & Tea, Food, Cocktail Bars, Nightlife, Event Planning & Services, Restaurants, Caterers, Wine Bars, Bars, Salad
# British, International Grocery, Grocery, Food, Ethnic Food, Herbal Shops, Restaurants, Health Markets, Specialty Food, Health & Medical
# Coffee & Tea, Food, Desserts, Turkish, Restaurants, Bakeries
# Restaurants, Middle Eastern, Bars, Nightlife, Mediterranean, Lebanese
# Restaurants, Seafood, Nightlife, Steakhouses, Bars, American (Traditional), Cocktail Bars, Wine Bars
# Burgers, Restaurants, Mexican
# Restaurants, Food, French, Coffee & Tea, Bakeries, Breakfast & Brunch
# Vietnamese, Restaurants, Noodles
# American (New), Breakfast & Brunch, Restaurants, Salad, Italian, Nightlife, Bars, Beer, Wine & Spirits, Sandwiches, Coffee & Tea, Wine Bars, Food, Pizza
# Restaurants, Ethiopian, French
# French, Cafes, Restaurants, Breakfast & Brunch, Food, Sandwiches, Bakeries
# American (Traditional), Coffee & Tea, Breakfast & Brunch, Food, Bakeries, Restaurants
# Pizza, Italian, Fast Food, Restaurants
# Restaurants, Breakfast & Brunch, Sandwiches, American (Traditional)
# Nightlife, Bars, Cocktail Bars, Food, American (New), Desserts, Restaurants
# Bars, Tapas/Small Plates, Japanese, Nightlife, Restaurants, Sushi Bars, Cocktail Bars, Asian Fusion
# Venues & Event Spaces, Cafes, Wine Bars, Event Planning & Services, Nightlife, Bars, Restaurants, American (New)
# Food, Breweries, Beer Gardens, Mediterranean, Nightlife, Restaurants
# Cocktail Bars, Farmers Market, Tapas Bars, Food, Desserts, Nightlife, Asian Fusion, Restaurants, Tapas/Small Plates, Bars, Indonesian
# Food, French, Cafes, Desserts, Bakeries, Restaurants, Breakfast & Brunch
# Breakfast & Brunch, Bocce Ball, Event Planning & Services, Beer, Wine & Spirits, Venues & Event Spaces, Italian, Active Life, Food, Wedding Planning, Restaurants
# Salad, Restaurants, Tacos, Mexican, Breakfast & Brunch
# Steakhouses, Cafes, American (Traditional), Seafood, Breakfast & Brunch, Restaurants, Sandwiches
# Restaurants, Tacos, Mexican
# Event Planning & Services, Caterers, Sandwiches, Bars, Steakhouses, Delis, Nightlife, Burgers, Cafes, American (New), Restaurants, American (Traditional)
# Nightlife, American (Traditional), Cafes, Restaurants, Wine Bars, Breakfast & Brunch, Bars
# Restaurants, Latin American, Mexican, Tacos
# Nightlife, Wine Bars, Bars, American (Traditional), Tapas/Small Plates, Tapas Bars, Food, Arts & Entertainment, Wine Tasting Room, Wineries, American (New), Restaurants
# Patisserie/Cake Shop, French, Food, Restaurants, Bakeries, Cupcakes
# Fast Food, Breakfast & Brunch, Restaurants, Mexican, Tex-Mex, Tacos
# Salad, Restaurants, Pizza, Sandwiches, Italian
# Modern European, Nightlife, Bars, Restaurants, Bakeries, Wine Bars, Food, Scandinavian, Breakfast & Brunch
# Restaurants, Gastropubs, Cocktail Bars, Bars, American (New), Nightlife, Beer Bar, American (Traditional)
# Indian, Food, Restaurants, Bubble Tea, Pakistani, Fast Food
# Vegan, Restaurants, Italian
# Seafood, American (Traditional), Breakfast & Brunch, Restaurants
# Restaurants, Food, Mexican, Bakeries
# Pizza, Nightlife, Italian, Restaurants, Bars
# Restaurants, Japanese
# Pubs, Bars, Food, American (Traditional), American (New), Nightlife, Breweries, Brewpubs, Restaurants
# Caterers, Restaurants, Spanish, Personal Chefs, Event Planning & Services
# Thai, Restaurants, Food, Donuts
# Bakeries, Sandwiches, Food, Restaurants, American (Traditional)
# Seafood, Restaurants, Hawaiian, American (New), Breakfast & Brunch
# American (Traditional), American (New), Nightlife, Bars, Beer Bar, Restaurants, Burgers
# Restaurants, Cocktail Bars, Salad, Bars, Burgers, American (New), Nightlife, Barbeque
# Restaurants, Nightlife, American (New), Food, Farmers Market, Bars, Wine Bars
# Seafood, Restaurants, Breakfast & Brunch, Lounges, Cocktail Bars, Mediterranean, Bars, Tapas/Small Plates, American (New), Nightlife
# Caterers, Italian, Restaurants, Delis, Event Planning & Services
# Japanese, Restaurants, Sushi Bars, Vegetarian
# Restaurants, Barbeque, Hawaiian
# Event Planning & Services, Nightlife, Tapas Bars, Spanish, Modern European, Bars, Cocktail Bars, Seafood, Venues & Event Spaces, Restaurants
# Garage Door Services, Restaurants, Live/Raw Food, Food, Home Services, Mediterranean, Keys & Locksmiths, Burgers, Vegetarian, Juice Bars & Smoothies, Vegan, Salad
# Vegan, Vegetarian, Restaurants, Indian
# American (New), Pizza, Pubs, Nightlife, Bars, Restaurants, American (Traditional), Breakfast & Brunch, Beer Bar
# Caterers, Restaurants, Mexican, Event Planning & Services, Food, Tacos, Bartenders, Food Delivery Services
# Bars, Wine Bars, American (New), Nightlife, Restaurants
# Breakfast & Brunch, Fast Food, Tex-Mex, Restaurants, Mexican, Tacos
# American (New), American (Traditional), Bars, Restaurants, Salad, Burgers, Ice Cream & Frozen Yogurt, Food, Nightlife, Beer, Wine & Spirits, Beer Bar, Chicken Shop
# Bars, Mediterranean, Restaurants, Nightlife, Moroccan, Event Planning & Services, Venues & Event Spaces, Italian
# Event Planning & Services, Latin American, Caterers, Food, Restaurants, Empanadas, Argentine
# Restaurants, Sandwiches, Nightlife, Bars, American (New), Cocktail Bars
# Pizza, Wine Bars, Restaurants, Venues & Event Spaces, Sandwiches, Cocktail Bars, American (New), Event Planning & Services, Burgers, Bars, Nightlife, Beer Bar
# Restaurants, Nightlife, Hotels & Travel, Hotels, Italian, Event Planning & Services
# Mexican, Restaurants, Fish & Chips
# Japanese, Restaurants, Noodles, Sushi Bars
# Restaurants, Japanese, Ramen
# Restaurants, Burgers, Food, Ice Cream & Frozen Yogurt, American (Traditional), Salad

# %%
df_filtrado.reset_index(drop=True, inplace=True)
df_filtrado.shape
# Out:
# (396, 12)

# %%
df_filtrado.head(5)
# Out:
#               business_id                  name  \
# 0  VeFfrEZ4iWaecrQg6Eq4cg              Cal Taco
# 1  bdfZdB2MTXlT6-RBjSIpQg            Pho Bistro
# 2  xwSWtJcQkzTF6HNm_IMgcg  Rusty's Pizza Parlor
# 3  18eWJFJbXyR9j_5xfcRLYA         Siam Elephant
# 4  MiMRlsXOpHJMSTDAuw8s1w             Su’s Bowl
#
#                              address         city postal_code   latitude  \
# 0          7320 Hollister Ave, Ste 1       Goleta       93117  34.430542
# 1          903 Embarcadero Del Norte   Isla Vista       93117  34.412934
# 2                      270 Storke Rd       Goleta       93117  34.429043
# 3                     509 Linden Ave  Carpinteria       93013   34.39651
# 4  901 Embarcadero Del Mar, Unit 100   Isla Vista       93117  34.412924
#
#     longitude stars review_count  \
# 0 -119.882367   4.0          189
# 1 -119.855531   3.0          184
# 2 -119.869362   2.5           94
# 3 -119.521681   4.5          460
# 4 -119.857337   3.5           18
#
#                                           attributes  \
# 0  {'RestaurantsGoodForGroups': 'True', 'Business...
# 1  {'RestaurantsDelivery': 'True', 'BikeParking':...
# 2  {'RestaurantsPriceRange2': '2', 'Alcohol': 'u'...
# 3  {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 4  {'RestaurantsTakeOut': 'True', 'BusinessAccept...
#
#                                           categories  \
# 0  Burgers, Cafes, Restaurants, Mexican, American...
# 1  Food, Restaurants, Chinese, Bubble Tea, Vietna...
# 2  Chicken Wings, Salad, Restaurants, Pizza, Ital...
# 3                                  Restaurants, Thai
# 4       Chinese, Restaurants, Asian Fusion, Szechuan
#
#                                                hours
# 0  {'Monday': '0:0-0:0', 'Tuesday': '8:0-20:30', ...
# 1  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 2  {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:0', ...
# 3  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-2...
# 4  {'Monday': '0:0-0:0', 'Tuesday': '17:0-21:0', ...

# %%
#Eliminamos la columna hours
df_filtrado.drop(columns=['hours'], inplace=True)
df_filtrado.head(5)
# Out:
#               business_id                  name  \
# 0  VeFfrEZ4iWaecrQg6Eq4cg              Cal Taco
# 1  bdfZdB2MTXlT6-RBjSIpQg            Pho Bistro
# 2  xwSWtJcQkzTF6HNm_IMgcg  Rusty's Pizza Parlor
# 3  18eWJFJbXyR9j_5xfcRLYA         Siam Elephant
# 4  MiMRlsXOpHJMSTDAuw8s1w             Su’s Bowl
#
#                              address         city postal_code   latitude  \
# 0          7320 Hollister Ave, Ste 1       Goleta       93117  34.430542
# 1          903 Embarcadero Del Norte   Isla Vista       93117  34.412934
# 2                      270 Storke Rd       Goleta       93117  34.429043
# 3                     509 Linden Ave  Carpinteria       93013   34.39651
# 4  901 Embarcadero Del Mar, Unit 100   Isla Vista       93117  34.412924
#
#     longitude stars review_count  \
# 0 -119.882367   4.0          189
# 1 -119.855531   3.0          184
# 2 -119.869362   2.5           94
# 3 -119.521681   4.5          460
# 4 -119.857337   3.5           18
#
#                                           attributes  \
# 0  {'RestaurantsGoodForGroups': 'True', 'Business...
# 1  {'RestaurantsDelivery': 'True', 'BikeParking':...
# 2  {'RestaurantsPriceRange2': '2', 'Alcohol': 'u'...
# 3  {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 4  {'RestaurantsTakeOut': 'True', 'BusinessAccept...
#
#                                           categories
# 0  Burgers, Cafes, Restaurants, Mexican, American...
# 1  Food, Restaurants, Chinese, Bubble Tea, Vietna...
# 2  Chicken Wings, Salad, Restaurants, Pizza, Ital...
# 3                                  Restaurants, Thai
# 4       Chinese, Restaurants, Asian Fusion, Szechuan

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   396 non-null    object
#  1   name          396 non-null    object
#  2   address       396 non-null    object
#  3   city          396 non-null    object
#  4   postal_code   396 non-null    object
#  5   latitude      396 non-null    object
#  6   longitude     396 non-null    object
#  7   stars         396 non-null    object
#  8   review_count  396 non-null    object
#  9   attributes    393 non-null    object
#  10  categories    396 non-null    object
# dtypes: object(11)
# memory usage: 34.2+ KB

# %%
#En nuestro dataset existen 396 opciones gastronomicas activas en California
len(df_filtrado['business_id'].unique())
# Out:
# 396

# %%
# Copiamos dos columnas del dataset para realizar la apertura por categorías
df_categories = df_filtrado.copy()
df_categories = df_categories[["business_id", "categories"]]
df_categories.head()
df_categories.to_csv('categorias.csv',index=False)

# %%
df_categories.shape
# Out:
# (396, 2)

# %%
# Realizamos un explode la columna anidada en categorías:
df_categories = df_categories.assign(categories=df_categories['categories'].str.split(',')).explode('categories')
df_categories["categories"] = df_categories["categories"].str.strip()
df_categories.shape
# Out:
# (2165, 2)

# %%
# Se seleccionan las categorías que vamos a analizar
categorias_interes = [
"American","American (Traditional)","American (New)","Argentine",
"Asian Fusion","Brazilian", "British","Caribbean","Chilean",
"Colombian","Cuban","Dominican","French","Hawaiian","Indian",
"Italian","Japanese","Korean","Latin American","Lebanese",
"Mediterranean","Mexican","MiddleEastern","Moroccan",
"Peruvian","Puerto Rican","Salvadoran","Scandinavian",
"Spanish","Thai","Turkish","Venezuelan","Vietnamese"
] 


# Se filtran las categorías en el dataframe
df_categories = df_categories[df_categories["categories"].isin(categorias_interes)]
df_categories.shape
# Out:
# (500, 2)

# %%
df_categories.head()
# Out:
#               business_id              categories
# 0  VeFfrEZ4iWaecrQg6Eq4cg                 Mexican
# 0  VeFfrEZ4iWaecrQg6Eq4cg  American (Traditional)
# 1  bdfZdB2MTXlT6-RBjSIpQg              Vietnamese
# 2  xwSWtJcQkzTF6HNm_IMgcg                 Italian
# 3  18eWJFJbXyR9j_5xfcRLYA                    Thai

# %%
# Se exporta el listado de categorías a un archivo parquet:
df_categories.to_parquet("categories_yelp.parquet")

# %%
# Se elimina la columna "categories" del df original:
df_filtrado.drop(columns=['categories'], inplace=True)
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   396 non-null    object
#  1   name          396 non-null    object
#  2   address       396 non-null    object
#  3   city          396 non-null    object
#  4   postal_code   396 non-null    object
#  5   latitude      396 non-null    object
#  6   longitude     396 non-null    object
#  7   stars         396 non-null    object
#  8   review_count  396 non-null    object
#  9   attributes    393 non-null    object
# dtypes: object(10)
# memory usage: 31.1+ KB

# %%
# Se crea una tabla nueva con los atributos de los restaurantes
atributos_restaurant = df_filtrado[["business_id", "attributes"]]
atributos_restaurant = pd.concat([atributos_restaurant, pd.json_normalize(atributos_restaurant["attributes"])], axis=1)
atributos_restaurant = atributos_restaurant.drop(columns="attributes")
atributos_restaurant.head()
# Out:
#               business_id RestaurantsGoodForGroups BusinessAcceptsCreditCards  \
# 0  VeFfrEZ4iWaecrQg6Eq4cg                     True                       True
# 1  bdfZdB2MTXlT6-RBjSIpQg                     True                       True
# 2  xwSWtJcQkzTF6HNm_IMgcg                     True                       True
# 3  18eWJFJbXyR9j_5xfcRLYA                     True                       True
# 4  MiMRlsXOpHJMSTDAuw8s1w                      NaN                       True
#
#       WiFi RestaurantsAttire RestaurantsPriceRange2 RestaurantsTakeOut  \
# 0    u'no'          'casual'                      1               True
# 1    u'no'         u'casual'                      1               True
# 2    u'no'          'casual'                      2               True
# 3    u'no'          'casual'                      2               True
# 4  u'free'               NaN                    NaN               True
#
#   GoodForKids HasTV RestaurantsReservations  ... ByAppointmentOnly CoatCheck  \
# 0        True  True                    True  ...               NaN       NaN
# 1        True  True                   False  ...               NaN       NaN
# 2        True  True                    True  ...               NaN       NaN
# 3        True  True                    True  ...             False       NaN
# 4         NaN  True                   False  ...               NaN       NaN
#
#   Music GoodForDancing BestNights Smoking AgesAllowed Open24Hours  \
# 0   NaN            NaN        NaN     NaN         NaN         NaN
# 1   NaN            NaN        NaN     NaN         NaN         NaN
# 2   NaN            NaN        NaN     NaN         NaN         NaN
# 3   NaN            NaN        NaN     NaN         NaN         NaN
# 4   NaN            NaN        NaN     NaN         NaN         NaN
#
#   DietaryRestrictions RestaurantsCounterService
# 0                 NaN                       NaN
# 1                 NaN                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN
#
# [5 rows x 38 columns]

# %%
atributos_restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   business_id                 396 non-null    object
#  1   RestaurantsGoodForGroups    326 non-null    object
#  2   BusinessAcceptsCreditCards  378 non-null    object
#  3   WiFi                        351 non-null    object
#  4   RestaurantsAttire           311 non-null    object
#  5   RestaurantsPriceRange2      349 non-null    object
#  6   RestaurantsTakeOut          384 non-null    object
#  7   GoodForKids                 319 non-null    object
#  8   HasTV                       360 non-null    object
#  9   RestaurantsReservations     355 non-null    object
#  10  BusinessParking             373 non-null    object
#  11  BusinessAcceptsBitcoin      108 non-null    object
#  12  NoiseLevel                  319 non-null    object
#  13  OutdoorSeating              377 non-null    object
#  14  BikeParking                 351 non-null    object
#  15  Caters                      340 non-null    object
#  16  RestaurantsTableService     254 non-null    object
#  17  RestaurantsDelivery         370 non-null    object
#  18  HappyHour                   199 non-null    object
#  19  DogsAllowed                 209 non-null    object
#  20  DriveThru                   72 non-null     object
#  21  WheelchairAccessible        203 non-null    object
#  22  Corkage                     105 non-null    object
#  23  Alcohol                     363 non-null    object
#  24  Ambience                    354 non-null    object
#  25  GoodForMeal                 317 non-null    object
#  26  BYOB                        98 non-null     object
#  27  BYOBCorkage                 36 non-null     object
#  28  ByAppointmentOnly           70 non-null     object
#  29  CoatCheck                   65 non-null     object
#  30  Music                       72 non-null     object
#  31  GoodForDancing              49 non-null     object
#  32  BestNights                  68 non-null     object
#  33  Smoking                     58 non-null     object
#  34  AgesAllowed                 2 non-null      object
#  35  Open24Hours                 1 non-null      object
#  36  DietaryRestrictions         1 non-null      object
#  37  RestaurantsCounterService   1 non-null      object
# dtypes: object(38)
# memory usage: 117.7+ KB

# %%
# Elimino la columna "attributes" del df original:
df_filtrado = df_filtrado.drop(columns="attributes")
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   396 non-null    object
#  1   name          396 non-null    object
#  2   address       396 non-null    object
#  3   city          396 non-null    object
#  4   postal_code   396 non-null    object
#  5   latitude      396 non-null    object
#  6   longitude     396 non-null    object
#  7   stars         396 non-null    object
#  8   review_count  396 non-null    object
# dtypes: object(9)
# memory usage: 28.0+ KB

# %%
# Se exportan ambos archivos en formato parquet:
df_filtrado.to_parquet("Restaurants_Yelp.parquet")

atributos_restaurant.to_parquet("Atributos_Restaurantes_Yelp.parquet")

# %%
df_filtrado.head()
# Out:
#               business_id                  name  \
# 0  VeFfrEZ4iWaecrQg6Eq4cg              Cal Taco
# 1  bdfZdB2MTXlT6-RBjSIpQg            Pho Bistro
# 2  xwSWtJcQkzTF6HNm_IMgcg  Rusty's Pizza Parlor
# 3  18eWJFJbXyR9j_5xfcRLYA         Siam Elephant
# 4  MiMRlsXOpHJMSTDAuw8s1w             Su’s Bowl
#
#                              address         city postal_code   latitude  \
# 0          7320 Hollister Ave, Ste 1       Goleta       93117  34.430542
# 1          903 Embarcadero Del Norte   Isla Vista       93117  34.412934
# 2                      270 Storke Rd       Goleta       93117  34.429043
# 3                     509 Linden Ave  Carpinteria       93013   34.39651
# 4  901 Embarcadero Del Mar, Unit 100   Isla Vista       93117  34.412924
#
#     longitude stars review_count
# 0 -119.882367   4.0          189
# 1 -119.855531   3.0          184
# 2 -119.869362   2.5           94
# 3 -119.521681   4.5          460
# 4 -119.857337   3.5           18

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   396 non-null    object
#  1   name          396 non-null    object
#  2   address       396 non-null    object
#  3   city          396 non-null    object
#  4   postal_code   396 non-null    object
#  5   latitude      396 non-null    object
#  6   longitude     396 non-null    object
#  7   stars         396 non-null    object
#  8   review_count  396 non-null    object
# dtypes: object(9)
# memory usage: 28.0+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df_filtrado['stars'] = df_filtrado['stars'].astype(float)

# Create the seaborn distplot
ax = sns.distplot(df_filtrado['stars'], bins=15, kde=False, color='RED', hist_kws={'edgecolor':'black'})

# Set the axes and spines to white
for spine in ax.spines.values():
    spine.set_color('white')

# Set the title, xlabel, and ylabel to white
ax.set_title('Puntaje de Stars', color='white')
ax.set_xlabel("No_de_(★★★)'s", color='white')
ax.set_ylabel('Frecuencia', color='white')

# Set tick labels to white
ax.tick_params(colors='white')

# Annotate the plot with the Unicode code
ax.annotate('★★★', xy=(0.5, 0.5), xycoords='axes fraction', color='white', fontsize=12)

plt.show()

# %%
# Filtramos por la ciudad de  Santa Barbara para ubicar su  ID y remplazarlo por el valor correcto
validar_duplicados = df_filtrado.duplicated(subset='city', keep=False)
Sin_duplicados = df_filtrado.duplicated(subset='city') == False
depuracion = df_filtrado[Sin_duplicados | ~validar_duplicados].copy()
Lista_ciudades = depuracion[depuracion['city'].str.startswith('Santa', na=False)]
print(Lista_ciudades[['city','business_id']])
# Out:
#                city             business_id
# 8     Santa Barbara  jW4a3W9-UkFxpglHvo_Kqg
# 336  Santa  Barbara  bBA62rVklEG2WUnvi8RtrQ

# %%
# Reemplazar el valor en la columna 'city' por el valor "Santa Barbara" para los índices donde el valor de la columna 'business_id' sea "bBA62rVklEG2WUnvi8RtrQ"
df_filtrado.loc[df_filtrado[df_filtrado['business_id'] == 'bBA62rVklEG2WUnvi8RtrQ'].index, 'city'] = 'Santa Barbara'

# Obtener el conteo de cada ciudad
city_count = df_filtrado['city'].value_counts()

# Crear un dataframe con el conteo de cada ciudad
df_city_count = pd.DataFrame({'city': city_count.index, 'count': city_count.values})

# Generar la gráfica utilizando seaborn
sns.set_style(rc={'axes.facecolor': 'black', 'figure.facecolor':'black'})
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='city', y='count', data=df_city_count, color='Gray', edgecolor='Black')

# Configurar los ejes y las etiquetas
plt.xlabel('Ciudad',color='Cyan')
plt.ylabel('Cantidad de negocios',color='Aqua')
plt.xticks(rotation=0,color='RED')
plt.title('Cantidad de negocios por ciudad', color='white')
ax.tick_params(colors='white')

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.0f}'.format(height),
            ha="center",
            color='yellow')

# Mostrar la gráfica
plt.show()

# %%
df_filtrado.to_parquet('df_business.parquet', index=False)
